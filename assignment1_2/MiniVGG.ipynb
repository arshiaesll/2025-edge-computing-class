# %%
import torch
import torch.nn as nn
from torch.utils.data import Dataset
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from contextlib import nullcontext
import uuid


class VGG(nn.Module):
    """
    A custom neural network architecture implemented using PyTorch.
    This class inherits from nn.Module, which is the base class for all neural network modules in PyTorch.
    """
    
    def __init__(self, input_channels, num_classes):
        """
        Initialize the network architecture.
        """
        super().__init__()

        self.block1 = nn.Sequential(
            nn.Conv2d(input_channels, 32, kernel_size=3, padding=1, stride=1),
            nn.ReLU(),
            nn.BatchNorm2d(32),
            nn.Conv2d(32, 32, kernel_size = 3, padding = 1, stride = 1),
            nn.ReLU(),
            nn.BatchNorm2d(32),
            nn.MaxPool2d(kernel_size=2, stride=2),
            nn.Dropout(p=0.25)
        )

        self.block2 = nn.Sequential(
            nn.Conv2d(32, 64, kernel_size=3, padding=1, stride=1),
            nn.ReLU(),
            nn.BatchNorm2d(64),
            nn.Conv2d(64, 64, kernel_size=3, padding=1, stride=1),
            nn.ReLU(),
            nn.BatchNorm2d(64),
            nn.MaxPool2d(kernel_size=2, stride=2),
            nn.Dropout(p=0.25)
        )

        self.classifier = nn.Sequential(
            nn.AdaptiveAvgPool2d((1, 1)),  # Global Average Pooling
            nn.Flatten(),
            nn.Dropout(p=0.5),
            nn.Linear(64, num_classes)  # Direct mapping from channels to classes
        )


    def forward(self, x):
        """
        Define the forward pass of the network. 
        """
        x = self.block1(x)
        x = self.block2(x)
        x = self.classifier(x)
        return x



class ImageDataset(Dataset):
    """
    Custom Dataset for loading image data from CSV file.
    The CSV file should contain image pixel values and labels.
    """
    def __init__(self, csv_file, transform=None, test=False):
        """
        Args:
            csv_file (str): Path to the csv file with image data
            transform (callable, optional): Optional transform to be applied on a sample
            test (bool): Whether this is test data (no labels)
        """
        # Read the CSV file
        self.data = pd.read_csv(csv_file)
        self.transform = transform
        self.test = test
        
        # Separate features (images) and labels
        if not test:
            self.images = self.data.iloc[:, 2:].values  # Skip id and label columns
            self.labels = self.data.iloc[:, 1].values   # Labels are in second column
        else:
            self.images = self.data.iloc[:, 1:].values  # Skip id column
        
        # Dictionary for class names
        self.class_map = {
            0: 'Airplane', 1: 'Automobile', 2: 'Bird', 3: 'Cat',
            4: 'Deer', 5: 'Dog', 6: 'Frog', 7: 'Horse',
            8: 'Ship', 9: 'Truck'
        }

    def __len__(self):
        """Returns the size of the dataset"""
        return len(self.data)

    def __getitem__(self, idx):
        """
        Returns a tuple (image, label) for the given index
        For test data, returns (image, 0) as a dummy label
        """
        if torch.is_tensor(idx):
            idx = idx.tolist()

        # First reshape to (32, 32, 3) for proper image layout
        image = self.images[idx].reshape(32, 32, 3).astype(np.uint8)
        
        # Get label if not test data, otherwise use dummy label
        label = self.labels[idx] if not self.test else 0

        # Convert to tensor and transpose to (3, 32, 32) for PyTorch
        image = torch.from_numpy(image).float() / 255.0
        image = image.permute(2, 0, 1)  # Change from (H,W,C) to (C,H,W)
        
        # Apply transforms if any
        if self.transform:
            image = self.transform(image)

        return image, label

    def save_sample(self, idx):
        """
        Display an image from the dataset
        Args:
            idx (int): Index of the image to display
        """
        image, label = self.__getitem__(idx)
        
        # Convert from (3, 32, 32) back to (32, 32, 3) for plotting
        image_np = (image.permute(1, 2, 0).numpy() * 255).astype(np.uint8)
        
        plt.figure(figsize=(4, 4))
        plt.imshow(image_np)
        plt.title(f'Class: {self.class_map[label]}')
        plt.axis('off')
        # plt.savefig(f'sample_{idx}.png')
        plt.imsave(f'sample_{idx}.png', image_np)


# Implement the datasets for train and test

class ModelManager:
    def __init__(self):
        print("Initializing Model")
        self.model = VGG(input_channels=3, num_classes=10)
        print("Initializing Train Dataset")
        self.train_dataset = ImageDataset('./competition_data/train.csv')
        self.batch_size = 32
        self.lr = 0.0001
        self.epochs = 100
        self.loss_fn = nn.CrossEntropyLoss()
        
        # Device selection logic
        if torch.cuda.is_available():
            self.device = torch.device('cuda')
            print("Using CUDA GPU")
        elif torch.backends.mps.is_available():
            self.device = torch.device('mps')
            print("Using Apple Metal (MPS)")
        else:
            self.device = torch.device('cpu')
            print("Using CPU")
            
        # Move model to the selected device
        self.model = self.model.to(self.device)
        self.optimizer = torch.optim.Adam(self.model.parameters(), lr=self.lr)
        
        self.train_dataloader = torch.utils.data.DataLoader(
            self.train_dataset,
            batch_size=self.batch_size,
            shuffle=True
        )
        self.val_dataset = ImageDataset('./competition_data/val.csv')
        self.val_dataloader = torch.utils.data.DataLoader(
            self.val_dataset,
            batch_size=self.batch_size,
            shuffle=True
        )
        os.makedirs('./models', exist_ok=True)
        self.model_save_path = './models'

    def train_model(self):
        train_lossses = []
        train_accuracies = []
        val_losses = []
        val_accuracies = []

        train_total_steps = len(self.train_dataloader)
        val_total_steps = len(self.val_dataloader)

        for epoch in range(self.epochs):
            self.model.train(True)

            train_loss, train_acc = self.train_validate(epoch, self.epochs, train_total_steps)
            val_loss, val_acc = self.train_validate(epoch, self.epochs, val_total_steps, validation=True)
            print("--------------------------------")
            print(f"End of Epoch {epoch + 1} / {self.epochs}")
            print (f"Epoch {epoch + 1} / {self.epochs} --> Val Loss: {val_loss} Val Acc: {val_acc}")
            print("--------------------------------")
            self.save_best_model(val_acc, val_accuracies, epoch)
            train_lossses.append(train_loss)
            train_accuracies.append(train_acc)
            val_losses.append(val_loss)
            val_accuracies.append(val_acc)


        return train_lossses, train_accuracies, val_losses, val_accuracies

    def train_validate(self, epoch: int, total_epochs: int, total_steps: int, validation : bool = False):
        
        running_acc = 0.0
        running_loss = 0.0
        
        # Set model to eval mode during validation
        self.model.train(not validation)
        
        context = torch.no_grad() if validation else nullcontext()
        with context:
            for i, (images, labels) in enumerate(self.val_dataloader if validation else self.train_dataloader):
                images = images.to(self.device)
                labels = labels.to(self.device)

                # Only zero gradients and do backward pass during training
                if not validation:
                    self.optimizer.zero_grad()
                
                outputs = self.model(images)
                loss = self.loss_fn(outputs, labels)
                accuracy = self.compute_accuracy(outputs, labels)

                # Only do backward pass and optimization during training
                if not validation:
                    loss.backward()
                    self.optimizer.step()

                running_loss += loss.item()
                running_acc += accuracy

                if (i + 1) % 100 == 0:
                    print(
                        f"{'Validation' if validation else 'Training'} --> " +
                        f"Epoch {epoch + 1} / {total_epochs} " +
                        f"Step {i + 1} / {total_steps} " +
                        f"Loss: {running_loss / (i+1):.4f} " +
                        f"Accuracy: {running_acc / (i+1):.4f}"
                    )
            
            running_loss = running_loss / total_steps
            running_acc = running_acc / total_steps
            return running_loss, running_acc


    def save_best_model(self, val_acc, val_accuracies, epoch):
        
        model_name = f'Model_MiniVGG_{epoch + 1}_{str(uuid.uuid4())[:4]}.pt'
        if len(val_accuracies) == 0:
            pass
        elif val_acc > max(val_accuracies):
            torch.save(self.model.state_dict(), os.path.join(self.model_save_path, model_name)) 
            with open('summary.txt', 'a') as f:
                f.write(f'{model_name},{val_acc:.4f}\n')



    def compute_accuracy(self, outputs, labels):
        predictions = torch.argmax(outputs, dim=1)

        num_predictions = len(predictions)
        num_incorrect = torch.count_nonzero(predictions - labels)

        accuracy = (num_predictions - num_incorrect) / num_predictions
        return accuracy


import torch
import time
import pandas as pd
from MiniVGG import ImageDataset, VGG
import os
import torch.quantization
import torch.nn.utils.prune as prune

def apply_pruning(model, amount=0.3):
    """Apply PyTorch's built-in pruning"""
    for name, module in model.named_modules():
        # Prune 30% of connections in all Conv2d layers
        if isinstance(module, torch.nn.Conv2d):
            prune.l1_unstructured(module, name='weight', amount=amount)
            # Make pruning permanent
            prune.remove(module, 'weight')
        # Prune 30% of connections in Linear layers
        elif isinstance(module, torch.nn.Linear):
            prune.l1_unstructured(module, name='weight', amount=amount)
            # Make pruning permanent
            prune.remove(module, 'weight')
    return model

def load_best_model():
    # Read summary.txt to find the best model
    with open('./summary.txt', 'r') as f:
        lines = f.readlines()
    
    # Parse model names and accuracies
    models = [(line.split(',')[0], float(line.split(',')[1])) for line in lines]
    # Get the model with highest accuracy
    best_model_name, best_accuracy = max(models, key=lambda x: x[1])
    print(f"Loading best model: {best_model_name} (accuracy: {best_accuracy:.4f})")
    expected_acc = best_accuracy
    
    # Load the model
    model = VGG(input_channels=3, num_classes=10)
    model.load_state_dict(torch.load(os.path.join('models', best_model_name), weights_only=True))
    model.eval()
    
    # Apply pruning
    # model = apply_pruning(model, amount=0.3)  # Prune 30% of weights
    print("Model pruned using PyTorch pruning!")
    
    # Convert to FP16
    model = model.half()
    print("Converted to FP16!")
    
    # Set device
    if torch.cuda.is_available():
        device = torch.device('cuda')
    elif torch.backends.mps.is_available():
        device = torch.device('mps')
        # Optimize model for inference using TorchScript
        try:
            print("Optimizing model for MPS...")
            model = model.to(device)
            # Create example input for tracing
            example_input = torch.randn(1, 3, 32, 32, dtype=torch.float16).to(device)
            # Script and optimize the model
            model = torch.jit.optimize_for_inference(
                torch.jit.script(model)
            )
            torch.backends.mps.graph_executor_enabled = True
            print("Model optimized successfully!")
        except Exception as e:
            print(f"Optimization failed, using standard model: {str(e)}")
    else:
        device = torch.device('cpu')
        model = model.to(device)
    # model = torch.compile(model, mode="reduce-overhead")

    return model, device, expected_acc

def run_benchmark():
    # Load model
    print("Loading best model...")
    model, device, expected_acc = load_best_model()
    
    # Load test dataset
    test_dataset = ImageDataset('./competition_data/test.csv', test=True)
    test_dataloader = torch.utils.data.DataLoader(
        test_dataset,
        batch_size=1,  # Process one sample at a time to measure latency
        shuffle=False
    )
    
    # Warm-up phase
    print("\nWarming up...")
    dummy_input = torch.randn(1, 3, 32, 32, dtype=torch.float16).to(device)
    with torch.no_grad():
            for _ in range(5):  # Run 100 warm-up inferences
                _ = model(dummy_input)
    print("Warm-up complete!")
    
    results = []
    print("\nRunning inference on test dataset...")
    # with torch.no_grad():  # Disable gradient computation for inference
    with torch.inference_mode(mode = True):
        for i, (image, _) in enumerate(test_dataloader):
            image = image.half().to(device)  # Convert to FP16
            
            # Measure inference time
            start_time = time.time()
            output = model(image)
            end_time = time.time()
            
            # Get prediction and latency
            prediction = torch.argmax(output, dim=1).item()
            latency = (end_time - start_time) * 1000  # Convert to milliseconds
            
            results.append({
                'id': i,
                'label': prediction,
                'latency': latency
            })
            
            if (i + 1) % 100 == 0:
                print(f"Processed {i + 1} samples...")
    
    # Save results
    df = pd.DataFrame(results)
    output_file = 'submission.csv'
    df.to_csv(output_file, index=False)
    print(f"Results saved to {output_file}")
    
    # Print summary statistics
    print("\nBenchmark Summary:")
    print(f"Average latency: {df['latency'].mean():.2f} ms")
    print(f"Min latency: {df['latency'].min():.2f} ms")
    print(f"Max latency: {df['latency'].max():.2f} ms")
    print(f"Expected Score: {expected_acc / df['latency'].mean()}")

# if __name__ == "__main__":
#     manager = ModelManager()
#     train_lossses, train_accuracies, val_losses, val_accuracies = manager.train_model()
#     run_benchmark()

# %% [markdown]
# ### Initialize Model

# %%
manager = ModelManager()
train_lossses, train_accuracies, val_losses, val_accuracies = manager.train_model()
# Out:
# Initializing Model
# Initializing Train Dataset
# Using Apple Metal (MPS)
# Training --> Epoch 1 / 100 Step 100 / 1313 Loss: 2.2738 Accuracy: 0.1781
# Training --> Epoch 1 / 100 Step 200 / 1313 Loss: 2.1800 Accuracy: 0.2041
# Training --> Epoch 1 / 100 Step 300 / 1313 Loss: 2.1214 Accuracy: 0.2242
# Training --> Epoch 1 / 100 Step 400 / 1313 Loss: 2.0713 Accuracy: 0.2416
# Training --> Epoch 1 / 100 Step 500 / 1313 Loss: 2.0356 Accuracy: 0.2522
# Training --> Epoch 1 / 100 Step 600 / 1313 Loss: 2.0024 Accuracy: 0.2629
# Training --> Epoch 1 / 100 Step 700 / 1313 Loss: 1.9733 Accuracy: 0.2729
# Training --> Epoch 1 / 100 Step 800 / 1313 Loss: 1.9456 Accuracy: 0.2832
# Training --> Epoch 1 / 100 Step 900 / 1313 Loss: 1.9239 Accuracy: 0.2911
# Training --> Epoch 1 / 100 Step 1000 / 1313 Loss: 1.9019 Accuracy: 0.3003
# Training --> Epoch 1 / 100 Step 1100 / 1313 Loss: 1.8788 Accuracy: 0.3091
# Training --> Epoch 1 / 100 Step 1200 / 1313 Loss: 1.8602 Accuracy: 0.3166
# Training --> Epoch 1 / 100 Step 1300 / 1313 Loss: 1.8429 Accuracy: 0.3235
# Validation --> Epoch 1 / 100 Step 100 / 516 Loss: 1.5361 Accuracy: 0.4606
# Validation --> Epoch 1 / 100 Step 200 / 516 Loss: 1.5278 Accuracy: 0.4714
# Validation --> Epoch 1 / 100 Step 300 / 516 Loss: 1.5372 Accuracy: 0.4646
# Validation --> Epoch 1 / 100 Step 400 / 516 Loss: 1.5353 Accuracy: 0.4632
# Validation --> Epoch 1 / 100 Step 500 / 516 Loss: 1.5309 Accuracy: 0.4653
# --------------------------------
# End of Epoch 1 / 100
# Epoch 1 / 100 --> Val Loss: 1.5302635006202283 Val Acc: 0.46554020047187805
# --------------------------------
# Training --> Epoch 2 / 100 Step 100 / 1313 Loss: 1.5902 Accuracy: 0.4175
# Training --> Epoch 2 / 100 Step 200 / 1313 Loss: 1.5968 Accuracy: 0.4137
# Training --> Epoch 2 / 100 Step 300 / 1313 Loss: 1.5831 Accuracy: 0.4243
# Training --> Epoch 2 / 100 Step 400 / 1313 Loss: 1.5772 Accuracy: 0.4270
# Training --> Epoch 2 / 100 Step 500 / 1313 Loss: 1.5772 Accuracy: 0.4267
# Training --> Epoch 2 / 100 Step 600 / 1313 Loss: 1.5716 Accuracy: 0.4288
# Training --> Epoch 2 / 100 Step 700 / 1313 Loss: 1.5660 Accuracy: 0.4311
# Training --> Epoch 2 / 100 Step 800 / 1313 Loss: 1.5603 Accuracy: 0.4331
# Training --> Epoch 2 / 100 Step 900 / 1313 Loss: 1.5557 Accuracy: 0.4350
# Training --> Epoch 2 / 100 Step 1000 / 1313 Loss: 1.5504 Accuracy: 0.4373
# Training --> Epoch 2 / 100 Step 1100 / 1313 Loss: 1.5481 Accuracy: 0.4388
# Training --> Epoch 2 / 100 Step 1200 / 1313 Loss: 1.5431 Accuracy: 0.4411
# Training --> Epoch 2 / 100 Step 1300 / 1313 Loss: 1.5389 Accuracy: 0.4423
# Validation --> Epoch 2 / 100 Step 100 / 516 Loss: 1.3527 Accuracy: 0.5344
# Validation --> Epoch 2 / 100 Step 200 / 516 Loss: 1.3619 Accuracy: 0.5300
# Validation --> Epoch 2 / 100 Step 300 / 516 Loss: 1.3579 Accuracy: 0.5276
# Validation --> Epoch 2 / 100 Step 400 / 516 Loss: 1.3623 Accuracy: 0.5241
# Validation --> Epoch 2 / 100 Step 500 / 516 Loss: 1.3641 Accuracy: 0.5214
# --------------------------------
# End of Epoch 2 / 100
# Epoch 2 / 100 --> Val Loss: 1.3638851309931554 Val Acc: 0.5213662385940552
# --------------------------------
# Training --> Epoch 3 / 100 Step 100 / 1313 Loss: 1.4339 Accuracy: 0.4884
# Training --> Epoch 3 / 100 Step 200 / 1313 Loss: 1.4545 Accuracy: 0.4777
# Training --> Epoch 3 / 100 Step 300 / 1313 Loss: 1.4595 Accuracy: 0.4786
# Training --> Epoch 3 / 100 Step 400 / 1313 Loss: 1.4523 Accuracy: 0.4821
# Training --> Epoch 3 / 100 Step 500 / 1313 Loss: 1.4492 Accuracy: 0.4832
# Training --> Epoch 3 / 100 Step 600 / 1313 Loss: 1.4454 Accuracy: 0.4833
# Training --> Epoch 3 / 100 Step 700 / 1313 Loss: 1.4392 Accuracy: 0.4857
# Training --> Epoch 3 / 100 Step 800 / 1313 Loss: 1.4317 Accuracy: 0.4895
# Training --> Epoch 3 / 100 Step 900 / 1313 Loss: 1.4288 Accuracy: 0.4898
# Training --> Epoch 3 / 100 Step 1000 / 1313 Loss: 1.4244 Accuracy: 0.4915
# Training --> Epoch 3 / 100 Step 1100 / 1313 Loss: 1.4195 Accuracy: 0.4935
# Training --> Epoch 3 / 100 Step 1200 / 1313 Loss: 1.4165 Accuracy: 0.4952
# Training --> Epoch 3 / 100 Step 1300 / 1313 Loss: 1.4123 Accuracy: 0.4971
# Validation --> Epoch 3 / 100 Step 100 / 516 Loss: 1.2788 Accuracy: 0.5431
# Validation --> Epoch 3 / 100 Step 200 / 516 Loss: 1.2733 Accuracy: 0.5472
# Validation --> Epoch 3 / 100 Step 300 / 516 Loss: 1.2830 Accuracy: 0.5415
# Validation --> Epoch 3 / 100 Step 400 / 516 Loss: 1.2881 Accuracy: 0.5423
# Validation --> Epoch 3 / 100 Step 500 / 516 Loss: 1.2849 Accuracy: 0.5439
# --------------------------------
# End of Epoch 3 / 100
# Epoch 3 / 100 --> Val Loss: 1.2864299453506174 Val Acc: 0.543883204460144
# --------------------------------
# Training --> Epoch 4 / 100 Step 100 / 1313 Loss: 1.3631 Accuracy: 0.5097
# Training --> Epoch 4 / 100 Step 200 / 1313 Loss: 1.3574 Accuracy: 0.5127
# Training --> Epoch 4 / 100 Step 300 / 1313 Loss: 1.3533 Accuracy: 0.5143
# Training --> Epoch 4 / 100 Step 400 / 1313 Loss: 1.3549 Accuracy: 0.5155
# Training --> Epoch 4 / 100 Step 500 / 1313 Loss: 1.3566 Accuracy: 0.5153
# Training --> Epoch 4 / 100 Step 600 / 1313 Loss: 1.3479 Accuracy: 0.5184
# Training --> Epoch 4 / 100 Step 700 / 1313 Loss: 1.3463 Accuracy: 0.5184
# Training --> Epoch 4 / 100 Step 800 / 1313 Loss: 1.3406 Accuracy: 0.5218
# Training --> Epoch 4 / 100 Step 900 / 1313 Loss: 1.3382 Accuracy: 0.5223
# Training --> Epoch 4 / 100 Step 1000 / 1313 Loss: 1.3371 Accuracy: 0.5231
# Training --> Epoch 4 / 100 Step 1100 / 1313 Loss: 1.3349 Accuracy: 0.5248
# Training --> Epoch 4 / 100 Step 1200 / 1313 Loss: 1.3293 Accuracy: 0.5277
# Training --> Epoch 4 / 100 Step 1300 / 1313 Loss: 1.3282 Accuracy: 0.5281
# Validation --> Epoch 4 / 100 Step 100 / 516 Loss: 1.2027 Accuracy: 0.5775
# Validation --> Epoch 4 / 100 Step 200 / 516 Loss: 1.1863 Accuracy: 0.5813
# Validation --> Epoch 4 / 100 Step 300 / 516 Loss: 1.1859 Accuracy: 0.5822
# Validation --> Epoch 4 / 100 Step 400 / 516 Loss: 1.1842 Accuracy: 0.5827
# Validation --> Epoch 4 / 100 Step 500 / 516 Loss: 1.1841 Accuracy: 0.5844
# --------------------------------
# End of Epoch 4 / 100
# Epoch 4 / 100 --> Val Loss: 1.1831954883974651 Val Acc: 0.585162341594696
# --------------------------------
# Training --> Epoch 5 / 100 Step 100 / 1313 Loss: 1.3114 Accuracy: 0.5391
# Training --> Epoch 5 / 100 Step 200 / 1313 Loss: 1.2882 Accuracy: 0.5491
# Training --> Epoch 5 / 100 Step 300 / 1313 Loss: 1.2682 Accuracy: 0.5571
# Training --> Epoch 5 / 100 Step 400 / 1313 Loss: 1.2638 Accuracy: 0.5588
# Training --> Epoch 5 / 100 Step 500 / 1313 Loss: 1.2646 Accuracy: 0.5558
# Training --> Epoch 5 / 100 Step 600 / 1313 Loss: 1.2668 Accuracy: 0.5538
# Training --> Epoch 5 / 100 Step 700 / 1313 Loss: 1.2649 Accuracy: 0.5542
# Training --> Epoch 5 / 100 Step 800 / 1313 Loss: 1.2606 Accuracy: 0.5554
# Training --> Epoch 5 / 100 Step 900 / 1313 Loss: 1.2622 Accuracy: 0.5558
# Training --> Epoch 5 / 100 Step 1000 / 1313 Loss: 1.2614 Accuracy: 0.5560
# Training --> Epoch 5 / 100 Step 1100 / 1313 Loss: 1.2605 Accuracy: 0.5564
# Training --> Epoch 5 / 100 Step 1200 / 1313 Loss: 1.2569 Accuracy: 0.5576
# Training --> Epoch 5 / 100 Step 1300 / 1313 Loss: 1.2552 Accuracy: 0.5585
# Validation --> Epoch 5 / 100 Step 100 / 516 Loss: 1.1097 Accuracy: 0.6156
# Validation --> Epoch 5 / 100 Step 200 / 516 Loss: 1.1200 Accuracy: 0.6078
# Validation --> Epoch 5 / 100 Step 300 / 516 Loss: 1.1191 Accuracy: 0.6090
# Validation --> Epoch 5 / 100 Step 400 / 516 Loss: 1.1153 Accuracy: 0.6095
# Validation --> Epoch 5 / 100 Step 500 / 516 Loss: 1.1098 Accuracy: 0.6128
# --------------------------------
# End of Epoch 5 / 100
# Epoch 5 / 100 --> Val Loss: 1.1112194098243418 Val Acc: 0.6127422451972961
# --------------------------------
# Training --> Epoch 6 / 100 Step 100 / 1313 Loss: 1.2282 Accuracy: 0.5734
# Training --> Epoch 6 / 100 Step 200 / 1313 Loss: 1.2297 Accuracy: 0.5709
# Training --> Epoch 6 / 100 Step 300 / 1313 Loss: 1.2177 Accuracy: 0.5730
# Training --> Epoch 6 / 100 Step 400 / 1313 Loss: 1.2224 Accuracy: 0.5705
# Training --> Epoch 6 / 100 Step 500 / 1313 Loss: 1.2185 Accuracy: 0.5730
# Training --> Epoch 6 / 100 Step 600 / 1313 Loss: 1.2125 Accuracy: 0.5748
# Training --> Epoch 6 / 100 Step 700 / 1313 Loss: 1.2100 Accuracy: 0.5765
# Training --> Epoch 6 / 100 Step 800 / 1313 Loss: 1.2076 Accuracy: 0.5779
# Training --> Epoch 6 / 100 Step 900 / 1313 Loss: 1.2096 Accuracy: 0.5774
# Training --> Epoch 6 / 100 Step 1000 / 1313 Loss: 1.2067 Accuracy: 0.5784
# Training --> Epoch 6 / 100 Step 1100 / 1313 Loss: 1.2034 Accuracy: 0.5797
# Training --> Epoch 6 / 100 Step 1200 / 1313 Loss: 1.2003 Accuracy: 0.5801
# Training --> Epoch 6 / 100 Step 1300 / 1313 Loss: 1.1993 Accuracy: 0.5805
# Validation --> Epoch 6 / 100 Step 100 / 516 Loss: 1.0816 Accuracy: 0.6184
# Validation --> Epoch 6 / 100 Step 200 / 516 Loss: 1.0747 Accuracy: 0.6183
# Validation --> Epoch 6 / 100 Step 300 / 516 Loss: 1.0791 Accuracy: 0.6161
# Validation --> Epoch 6 / 100 Step 400 / 516 Loss: 1.0798 Accuracy: 0.6166
# Validation --> Epoch 6 / 100 Step 500 / 516 Loss: 1.0755 Accuracy: 0.6169
# --------------------------------
# End of Epoch 6 / 100
# Epoch 6 / 100 --> Val Loss: 1.0763720821502596 Val Acc: 0.6161336898803711
# --------------------------------
# Training --> Epoch 7 / 100 Step 100 / 1313 Loss: 1.1556 Accuracy: 0.5966
# Training --> Epoch 7 / 100 Step 200 / 1313 Loss: 1.1686 Accuracy: 0.5947
# Training --> Epoch 7 / 100 Step 300 / 1313 Loss: 1.1681 Accuracy: 0.5913
# Training --> Epoch 7 / 100 Step 400 / 1313 Loss: 1.1673 Accuracy: 0.5880
# Training --> Epoch 7 / 100 Step 500 / 1313 Loss: 1.1674 Accuracy: 0.5897
# Training --> Epoch 7 / 100 Step 600 / 1313 Loss: 1.1688 Accuracy: 0.5882
# Training --> Epoch 7 / 100 Step 700 / 1313 Loss: 1.1675 Accuracy: 0.5880
# Training --> Epoch 7 / 100 Step 800 / 1313 Loss: 1.1629 Accuracy: 0.5907
# Training --> Epoch 7 / 100 Step 900 / 1313 Loss: 1.1607 Accuracy: 0.5917
# Training --> Epoch 7 / 100 Step 1000 / 1313 Loss: 1.1582 Accuracy: 0.5928
# Training --> Epoch 7 / 100 Step 1100 / 1313 Loss: 1.1589 Accuracy: 0.5915
# Training --> Epoch 7 / 100 Step 1200 / 1313 Loss: 1.1582 Accuracy: 0.5920
# Training --> Epoch 7 / 100 Step 1300 / 1313 Loss: 1.1561 Accuracy: 0.5923
# Validation --> Epoch 7 / 100 Step 100 / 516 Loss: 1.0330 Accuracy: 0.6306
# Validation --> Epoch 7 / 100 Step 200 / 516 Loss: 1.0260 Accuracy: 0.6338
# Validation --> Epoch 7 / 100 Step 300 / 516 Loss: 1.0169 Accuracy: 0.6403
# Validation --> Epoch 7 / 100 Step 400 / 516 Loss: 1.0144 Accuracy: 0.6385
# Validation --> Epoch 7 / 100 Step 500 / 516 Loss: 1.0144 Accuracy: 0.6390
# --------------------------------
# End of Epoch 7 / 100
# Epoch 7 / 100 --> Val Loss: 1.0164996145307557 Val Acc: 0.6381298303604126
# --------------------------------
# Training --> Epoch 8 / 100 Step 100 / 1313 Loss: 1.1289 Accuracy: 0.5994
# Training --> Epoch 8 / 100 Step 200 / 1313 Loss: 1.1249 Accuracy: 0.6052
# Training --> Epoch 8 / 100 Step 300 / 1313 Loss: 1.1254 Accuracy: 0.6052
# Training --> Epoch 8 / 100 Step 400 / 1313 Loss: 1.1247 Accuracy: 0.6054
# Training --> Epoch 8 / 100 Step 500 / 1313 Loss: 1.1221 Accuracy: 0.6045
# Training --> Epoch 8 / 100 Step 600 / 1313 Loss: 1.1221 Accuracy: 0.6056
# Training --> Epoch 8 / 100 Step 700 / 1313 Loss: 1.1235 Accuracy: 0.6057
# Training --> Epoch 8 / 100 Step 800 / 1313 Loss: 1.1240 Accuracy: 0.6050
# Training --> Epoch 8 / 100 Step 900 / 1313 Loss: 1.1222 Accuracy: 0.6057
# Training --> Epoch 8 / 100 Step 1000 / 1313 Loss: 1.1243 Accuracy: 0.6042
# Training --> Epoch 8 / 100 Step 1100 / 1313 Loss: 1.1225 Accuracy: 0.6044
# Training --> Epoch 8 / 100 Step 1200 / 1313 Loss: 1.1183 Accuracy: 0.6062
# Training --> Epoch 8 / 100 Step 1300 / 1313 Loss: 1.1189 Accuracy: 0.6057
# Validation --> Epoch 8 / 100 Step 100 / 516 Loss: 1.0106 Accuracy: 0.6344
# Validation --> Epoch 8 / 100 Step 200 / 516 Loss: 1.0079 Accuracy: 0.6394
# Validation --> Epoch 8 / 100 Step 300 / 516 Loss: 0.9992 Accuracy: 0.6459
# Validation --> Epoch 8 / 100 Step 400 / 516 Loss: 1.0014 Accuracy: 0.6452
# Validation --> Epoch 8 / 100 Step 500 / 516 Loss: 0.9969 Accuracy: 0.6465
# --------------------------------
# End of Epoch 8 / 100
# Epoch 8 / 100 --> Val Loss: 0.9978486425423807 Val Acc: 0.6453609466552734
# --------------------------------
# Training --> Epoch 9 / 100 Step 100 / 1313 Loss: 1.1292 Accuracy: 0.6016
# Training --> Epoch 9 / 100 Step 200 / 1313 Loss: 1.1148 Accuracy: 0.6070
# Training --> Epoch 9 / 100 Step 300 / 1313 Loss: 1.1075 Accuracy: 0.6107
# Training --> Epoch 9 / 100 Step 400 / 1313 Loss: 1.1062 Accuracy: 0.6113
# Training --> Epoch 9 / 100 Step 500 / 1313 Loss: 1.0969 Accuracy: 0.6167
# Training --> Epoch 9 / 100 Step 600 / 1313 Loss: 1.0913 Accuracy: 0.6182
# Training --> Epoch 9 / 100 Step 700 / 1313 Loss: 1.0891 Accuracy: 0.6183
# Training --> Epoch 9 / 100 Step 800 / 1313 Loss: 1.0882 Accuracy: 0.6183
# Training --> Epoch 9 / 100 Step 900 / 1313 Loss: 1.0887 Accuracy: 0.6183
# Training --> Epoch 9 / 100 Step 1000 / 1313 Loss: 1.0862 Accuracy: 0.6193
# Training --> Epoch 9 / 100 Step 1100 / 1313 Loss: 1.0863 Accuracy: 0.6197
# Training --> Epoch 9 / 100 Step 1200 / 1313 Loss: 1.0868 Accuracy: 0.6188
# Training --> Epoch 9 / 100 Step 1300 / 1313 Loss: 1.0881 Accuracy: 0.6176
# Validation --> Epoch 9 / 100 Step 100 / 516 Loss: 0.9550 Accuracy: 0.6584
# Validation --> Epoch 9 / 100 Step 200 / 516 Loss: 0.9529 Accuracy: 0.6553
# Validation --> Epoch 9 / 100 Step 300 / 516 Loss: 0.9522 Accuracy: 0.6558
# Validation --> Epoch 9 / 100 Step 400 / 516 Loss: 0.9528 Accuracy: 0.6573
# Validation --> Epoch 9 / 100 Step 500 / 516 Loss: 0.9566 Accuracy: 0.6569
# --------------------------------
# End of Epoch 9 / 100
# Epoch 9 / 100 --> Val Loss: 0.9548138660169387 Val Acc: 0.6574733853340149
# --------------------------------
# Training --> Epoch 10 / 100 Step 100 / 1313 Loss: 1.0433 Accuracy: 0.6431
# Training --> Epoch 10 / 100 Step 200 / 1313 Loss: 1.0623 Accuracy: 0.6341
# Training --> Epoch 10 / 100 Step 300 / 1313 Loss: 1.0650 Accuracy: 0.6317
# Training --> Epoch 10 / 100 Step 400 / 1313 Loss: 1.0680 Accuracy: 0.6295
# Training --> Epoch 10 / 100 Step 500 / 1313 Loss: 1.0660 Accuracy: 0.6296
# Training --> Epoch 10 / 100 Step 600 / 1313 Loss: 1.0650 Accuracy: 0.6285
# Training --> Epoch 10 / 100 Step 700 / 1313 Loss: 1.0657 Accuracy: 0.6279
# Training --> Epoch 10 / 100 Step 800 / 1313 Loss: 1.0623 Accuracy: 0.6280
# Training --> Epoch 10 / 100 Step 900 / 1313 Loss: 1.0628 Accuracy: 0.6286
# Training --> Epoch 10 / 100 Step 1000 / 1313 Loss: 1.0635 Accuracy: 0.6286
# Training --> Epoch 10 / 100 Step 1100 / 1313 Loss: 1.0630 Accuracy: 0.6283
# Training --> Epoch 10 / 100 Step 1200 / 1313 Loss: 1.0631 Accuracy: 0.6285
# Training --> Epoch 10 / 100 Step 1300 / 1313 Loss: 1.0636 Accuracy: 0.6279
# Validation --> Epoch 10 / 100 Step 100 / 516 Loss: 0.9511 Accuracy: 0.6644
# Validation --> Epoch 10 / 100 Step 200 / 516 Loss: 0.9527 Accuracy: 0.6627
# Validation --> Epoch 10 / 100 Step 300 / 516 Loss: 0.9627 Accuracy: 0.6573
# Validation --> Epoch 10 / 100 Step 400 / 516 Loss: 0.9625 Accuracy: 0.6570
# Validation --> Epoch 10 / 100 Step 500 / 516 Loss: 0.9684 Accuracy: 0.6532
# --------------------------------
# End of Epoch 10 / 100
# Epoch 10 / 100 --> Val Loss: 0.9699804171804309 Val Acc: 0.6521075367927551
# --------------------------------
# Training --> Epoch 11 / 100 Step 100 / 1313 Loss: 1.0194 Accuracy: 0.6494
# Training --> Epoch 11 / 100 Step 200 / 1313 Loss: 1.0303 Accuracy: 0.6414
# Training --> Epoch 11 / 100 Step 300 / 1313 Loss: 1.0394 Accuracy: 0.6409
# Training --> Epoch 11 / 100 Step 400 / 1313 Loss: 1.0463 Accuracy: 0.6381
# Training --> Epoch 11 / 100 Step 500 / 1313 Loss: 1.0483 Accuracy: 0.6348
# Training --> Epoch 11 / 100 Step 600 / 1313 Loss: 1.0481 Accuracy: 0.6361
# Training --> Epoch 11 / 100 Step 700 / 1313 Loss: 1.0484 Accuracy: 0.6348
# Training --> Epoch 11 / 100 Step 800 / 1313 Loss: 1.0462 Accuracy: 0.6350
# Training --> Epoch 11 / 100 Step 900 / 1313 Loss: 1.0473 Accuracy: 0.6352
# Training --> Epoch 11 / 100 Step 1000 / 1313 Loss: 1.0417 Accuracy: 0.6380
# Training --> Epoch 11 / 100 Step 1100 / 1313 Loss: 1.0412 Accuracy: 0.6381
# Training --> Epoch 11 / 100 Step 1200 / 1313 Loss: 1.0388 Accuracy: 0.6385
# Training --> Epoch 11 / 100 Step 1300 / 1313 Loss: 1.0382 Accuracy: 0.6392
# Validation --> Epoch 11 / 100 Step 100 / 516 Loss: 0.8935 Accuracy: 0.6869
# Validation --> Epoch 11 / 100 Step 200 / 516 Loss: 0.8950 Accuracy: 0.6814
# Validation --> Epoch 11 / 100 Step 300 / 516 Loss: 0.9022 Accuracy: 0.6797
# Validation --> Epoch 11 / 100 Step 400 / 516 Loss: 0.9002 Accuracy: 0.6793
# Validation --> Epoch 11 / 100 Step 500 / 516 Loss: 0.9053 Accuracy: 0.6777
# --------------------------------
# End of Epoch 11 / 100
# Epoch 11 / 100 --> Val Loss: 0.9056038147834844 Val Acc: 0.6771560311317444
# --------------------------------
# Training --> Epoch 12 / 100 Step 100 / 1313 Loss: 1.0427 Accuracy: 0.6313
# Training --> Epoch 12 / 100 Step 200 / 1313 Loss: 1.0309 Accuracy: 0.6339
# Training --> Epoch 12 / 100 Step 300 / 1313 Loss: 1.0326 Accuracy: 0.6368
# Training --> Epoch 12 / 100 Step 400 / 1313 Loss: 1.0362 Accuracy: 0.6373
# Training --> Epoch 12 / 100 Step 500 / 1313 Loss: 1.0321 Accuracy: 0.6394
# Training --> Epoch 12 / 100 Step 600 / 1313 Loss: 1.0284 Accuracy: 0.6414
# Training --> Epoch 12 / 100 Step 700 / 1313 Loss: 1.0237 Accuracy: 0.6417
# Training --> Epoch 12 / 100 Step 800 / 1313 Loss: 1.0241 Accuracy: 0.6416
# Training --> Epoch 12 / 100 Step 900 / 1313 Loss: 1.0224 Accuracy: 0.6430
# Training --> Epoch 12 / 100 Step 1000 / 1313 Loss: 1.0226 Accuracy: 0.6431
# Training --> Epoch 12 / 100 Step 1100 / 1313 Loss: 1.0207 Accuracy: 0.6442
# Training --> Epoch 12 / 100 Step 1200 / 1313 Loss: 1.0219 Accuracy: 0.6438
# Training --> Epoch 12 / 100 Step 1300 / 1313 Loss: 1.0228 Accuracy: 0.6432
# Validation --> Epoch 12 / 100 Step 100 / 516 Loss: 0.9262 Accuracy: 0.6581
# Validation --> Epoch 12 / 100 Step 200 / 516 Loss: 0.9234 Accuracy: 0.6644
# Validation --> Epoch 12 / 100 Step 300 / 516 Loss: 0.9220 Accuracy: 0.6664
# Validation --> Epoch 12 / 100 Step 400 / 516 Loss: 0.9230 Accuracy: 0.6687
# Validation --> Epoch 12 / 100 Step 500 / 516 Loss: 0.9271 Accuracy: 0.6679
# --------------------------------
# End of Epoch 12 / 100
# Epoch 12 / 100 --> Val Loss: 0.9262295564015707 Val Acc: 0.6679747700691223
# --------------------------------
# Training --> Epoch 13 / 100 Step 100 / 1313 Loss: 1.0228 Accuracy: 0.6422
# Training --> Epoch 13 / 100 Step 200 / 1313 Loss: 1.0373 Accuracy: 0.6350
# Training --> Epoch 13 / 100 Step 300 / 1313 Loss: 1.0372 Accuracy: 0.6366
# Training --> Epoch 13 / 100 Step 400 / 1313 Loss: 1.0324 Accuracy: 0.6398
# Training --> Epoch 13 / 100 Step 500 / 1313 Loss: 1.0274 Accuracy: 0.6425
# Training --> Epoch 13 / 100 Step 600 / 1313 Loss: 1.0210 Accuracy: 0.6445
# Training --> Epoch 13 / 100 Step 700 / 1313 Loss: 1.0242 Accuracy: 0.6447
# Training --> Epoch 13 / 100 Step 800 / 1313 Loss: 1.0187 Accuracy: 0.6450
# Training --> Epoch 13 / 100 Step 900 / 1313 Loss: 1.0168 Accuracy: 0.6463
# Training --> Epoch 13 / 100 Step 1000 / 1313 Loss: 1.0122 Accuracy: 0.6475
# Training --> Epoch 13 / 100 Step 1100 / 1313 Loss: 1.0101 Accuracy: 0.6486
# Training --> Epoch 13 / 100 Step 1200 / 1313 Loss: 1.0089 Accuracy: 0.6485
# Training --> Epoch 13 / 100 Step 1300 / 1313 Loss: 1.0064 Accuracy: 0.6491
# Validation --> Epoch 13 / 100 Step 100 / 516 Loss: 0.8610 Accuracy: 0.6950
# Validation --> Epoch 13 / 100 Step 200 / 516 Loss: 0.8786 Accuracy: 0.6867
# Validation --> Epoch 13 / 100 Step 300 / 516 Loss: 0.8739 Accuracy: 0.6893
# Validation --> Epoch 13 / 100 Step 400 / 516 Loss: 0.8797 Accuracy: 0.6876
# Validation --> Epoch 13 / 100 Step 500 / 516 Loss: 0.8787 Accuracy: 0.6876
# --------------------------------
# End of Epoch 13 / 100
# Epoch 13 / 100 --> Val Loss: 0.8793596839604452 Val Acc: 0.68740314245224
# --------------------------------
# Training --> Epoch 14 / 100 Step 100 / 1313 Loss: 0.9957 Accuracy: 0.6572
# Training --> Epoch 14 / 100 Step 200 / 1313 Loss: 0.9926 Accuracy: 0.6553
# Training --> Epoch 14 / 100 Step 300 / 1313 Loss: 0.9824 Accuracy: 0.6580
# Training --> Epoch 14 / 100 Step 400 / 1313 Loss: 0.9807 Accuracy: 0.6569
# Training --> Epoch 14 / 100 Step 500 / 1313 Loss: 0.9774 Accuracy: 0.6591
# Training --> Epoch 14 / 100 Step 600 / 1313 Loss: 0.9796 Accuracy: 0.6586
# Training --> Epoch 14 / 100 Step 700 / 1313 Loss: 0.9805 Accuracy: 0.6579
# Training --> Epoch 14 / 100 Step 800 / 1313 Loss: 0.9842 Accuracy: 0.6568
# Training --> Epoch 14 / 100 Step 900 / 1313 Loss: 0.9841 Accuracy: 0.6574
# Training --> Epoch 14 / 100 Step 1000 / 1313 Loss: 0.9835 Accuracy: 0.6568
# Training --> Epoch 14 / 100 Step 1100 / 1313 Loss: 0.9826 Accuracy: 0.6575
# Training --> Epoch 14 / 100 Step 1200 / 1313 Loss: 0.9852 Accuracy: 0.6560
# Training --> Epoch 14 / 100 Step 1300 / 1313 Loss: 0.9835 Accuracy: 0.6567
# Validation --> Epoch 14 / 100 Step 100 / 516 Loss: 0.8637 Accuracy: 0.6878
# Validation --> Epoch 14 / 100 Step 200 / 516 Loss: 0.8750 Accuracy: 0.6844
# Validation --> Epoch 14 / 100 Step 300 / 516 Loss: 0.8801 Accuracy: 0.6824
# Validation --> Epoch 14 / 100 Step 400 / 516 Loss: 0.8853 Accuracy: 0.6814
# Validation --> Epoch 14 / 100 Step 500 / 516 Loss: 0.8834 Accuracy: 0.6817
# --------------------------------
# End of Epoch 14 / 100
# Epoch 14 / 100 --> Val Loss: 0.8816313855061235 Val Acc: 0.6824491024017334
# --------------------------------
# Training --> Epoch 15 / 100 Step 100 / 1313 Loss: 0.9568 Accuracy: 0.6691
# Training --> Epoch 15 / 100 Step 200 / 1313 Loss: 0.9563 Accuracy: 0.6652
# Training --> Epoch 15 / 100 Step 300 / 1313 Loss: 0.9610 Accuracy: 0.6654
# Training --> Epoch 15 / 100 Step 400 / 1313 Loss: 0.9652 Accuracy: 0.6628
# Training --> Epoch 15 / 100 Step 500 / 1313 Loss: 0.9678 Accuracy: 0.6619
# Training --> Epoch 15 / 100 Step 600 / 1313 Loss: 0.9682 Accuracy: 0.6619
# Training --> Epoch 15 / 100 Step 700 / 1313 Loss: 0.9690 Accuracy: 0.6615
# Training --> Epoch 15 / 100 Step 800 / 1313 Loss: 0.9655 Accuracy: 0.6630
# Training --> Epoch 15 / 100 Step 900 / 1313 Loss: 0.9684 Accuracy: 0.6624
# Training --> Epoch 15 / 100 Step 1000 / 1313 Loss: 0.9701 Accuracy: 0.6621
# Training --> Epoch 15 / 100 Step 1100 / 1313 Loss: 0.9694 Accuracy: 0.6626
# Training --> Epoch 15 / 100 Step 1200 / 1313 Loss: 0.9694 Accuracy: 0.6624
# Training --> Epoch 15 / 100 Step 1300 / 1313 Loss: 0.9700 Accuracy: 0.6623
# Validation --> Epoch 15 / 100 Step 100 / 516 Loss: 0.8562 Accuracy: 0.6944
# Validation --> Epoch 15 / 100 Step 200 / 516 Loss: 0.8514 Accuracy: 0.6973
# Validation --> Epoch 15 / 100 Step 300 / 516 Loss: 0.8648 Accuracy: 0.6940
# Validation --> Epoch 15 / 100 Step 400 / 516 Loss: 0.8643 Accuracy: 0.6927
# Validation --> Epoch 15 / 100 Step 500 / 516 Loss: 0.8676 Accuracy: 0.6908
# --------------------------------
# End of Epoch 15 / 100
# Epoch 15 / 100 --> Val Loss: 0.8667054668415425 Val Acc: 0.6907703280448914
# --------------------------------
# Training --> Epoch 16 / 100 Step 100 / 1313 Loss: 0.9853 Accuracy: 0.6578
# Training --> Epoch 16 / 100 Step 200 / 1313 Loss: 0.9551 Accuracy: 0.6691
# Training --> Epoch 16 / 100 Step 300 / 1313 Loss: 0.9431 Accuracy: 0.6734
# Training --> Epoch 16 / 100 Step 400 / 1313 Loss: 0.9457 Accuracy: 0.6710
# Training --> Epoch 16 / 100 Step 500 / 1313 Loss: 0.9454 Accuracy: 0.6718
# Training --> Epoch 16 / 100 Step 600 / 1313 Loss: 0.9451 Accuracy: 0.6705
# Training --> Epoch 16 / 100 Step 700 / 1313 Loss: 0.9460 Accuracy: 0.6706
# Training --> Epoch 16 / 100 Step 800 / 1313 Loss: 0.9509 Accuracy: 0.6693
# Training --> Epoch 16 / 100 Step 900 / 1313 Loss: 0.9521 Accuracy: 0.6695
# Training --> Epoch 16 / 100 Step 1000 / 1313 Loss: 0.9536 Accuracy: 0.6688
# Training --> Epoch 16 / 100 Step 1100 / 1313 Loss: 0.9533 Accuracy: 0.6693
# Training --> Epoch 16 / 100 Step 1200 / 1313 Loss: 0.9515 Accuracy: 0.6705
# Training --> Epoch 16 / 100 Step 1300 / 1313 Loss: 0.9537 Accuracy: 0.6695
# Validation --> Epoch 16 / 100 Step 100 / 516 Loss: 0.8468 Accuracy: 0.7028
# Validation --> Epoch 16 / 100 Step 200 / 516 Loss: 0.8538 Accuracy: 0.6969
# Validation --> Epoch 16 / 100 Step 300 / 516 Loss: 0.8494 Accuracy: 0.6994
# Validation --> Epoch 16 / 100 Step 400 / 516 Loss: 0.8413 Accuracy: 0.7049
# Validation --> Epoch 16 / 100 Step 500 / 516 Loss: 0.8412 Accuracy: 0.7038
# --------------------------------
# End of Epoch 16 / 100
# Epoch 16 / 100 --> Val Loss: 0.8417521881502729 Val Acc: 0.7032461166381836
# --------------------------------
# Training --> Epoch 17 / 100 Step 100 / 1313 Loss: 0.9494 Accuracy: 0.6644
# Training --> Epoch 17 / 100 Step 200 / 1313 Loss: 0.9401 Accuracy: 0.6703
# Training --> Epoch 17 / 100 Step 300 / 1313 Loss: 0.9511 Accuracy: 0.6658
# Training --> Epoch 17 / 100 Step 400 / 1313 Loss: 0.9420 Accuracy: 0.6695
# Training --> Epoch 17 / 100 Step 500 / 1313 Loss: 0.9451 Accuracy: 0.6703
# Training --> Epoch 17 / 100 Step 600 / 1313 Loss: 0.9460 Accuracy: 0.6696
# Training --> Epoch 17 / 100 Step 700 / 1313 Loss: 0.9377 Accuracy: 0.6735
# Training --> Epoch 17 / 100 Step 800 / 1313 Loss: 0.9392 Accuracy: 0.6733
# Training --> Epoch 17 / 100 Step 900 / 1313 Loss: 0.9385 Accuracy: 0.6731
# Training --> Epoch 17 / 100 Step 1000 / 1313 Loss: 0.9384 Accuracy: 0.6724
# Training --> Epoch 17 / 100 Step 1100 / 1313 Loss: 0.9405 Accuracy: 0.6711
# Training --> Epoch 17 / 100 Step 1200 / 1313 Loss: 0.9403 Accuracy: 0.6715
# Training --> Epoch 17 / 100 Step 1300 / 1313 Loss: 0.9392 Accuracy: 0.6711
# Validation --> Epoch 17 / 100 Step 100 / 516 Loss: 0.8554 Accuracy: 0.7006
# Validation --> Epoch 17 / 100 Step 200 / 516 Loss: 0.8427 Accuracy: 0.7016
# Validation --> Epoch 17 / 100 Step 300 / 516 Loss: 0.8336 Accuracy: 0.7044
# Validation --> Epoch 17 / 100 Step 400 / 516 Loss: 0.8350 Accuracy: 0.7045
# Validation --> Epoch 17 / 100 Step 500 / 516 Loss: 0.8340 Accuracy: 0.7020
# --------------------------------
# End of Epoch 17 / 100
# Epoch 17 / 100 --> Val Loss: 0.8324337361972461 Val Acc: 0.7023861408233643
# --------------------------------
# Training --> Epoch 18 / 100 Step 100 / 1313 Loss: 0.9482 Accuracy: 0.6772
# Training --> Epoch 18 / 100 Step 200 / 1313 Loss: 0.9513 Accuracy: 0.6697
# Training --> Epoch 18 / 100 Step 300 / 1313 Loss: 0.9382 Accuracy: 0.6739
# Training --> Epoch 18 / 100 Step 400 / 1313 Loss: 0.9310 Accuracy: 0.6779
# Training --> Epoch 18 / 100 Step 500 / 1313 Loss: 0.9340 Accuracy: 0.6761
# Training --> Epoch 18 / 100 Step 600 / 1313 Loss: 0.9369 Accuracy: 0.6737
# Training --> Epoch 18 / 100 Step 700 / 1313 Loss: 0.9366 Accuracy: 0.6733
# Training --> Epoch 18 / 100 Step 800 / 1313 Loss: 0.9378 Accuracy: 0.6731
# Training --> Epoch 18 / 100 Step 900 / 1313 Loss: 0.9341 Accuracy: 0.6744
# Training --> Epoch 18 / 100 Step 1000 / 1313 Loss: 0.9310 Accuracy: 0.6758
# Training --> Epoch 18 / 100 Step 1100 / 1313 Loss: 0.9318 Accuracy: 0.6756
# Training --> Epoch 18 / 100 Step 1200 / 1313 Loss: 0.9295 Accuracy: 0.6769
# Training --> Epoch 18 / 100 Step 1300 / 1313 Loss: 0.9288 Accuracy: 0.6773
# Validation --> Epoch 18 / 100 Step 100 / 516 Loss: 0.8291 Accuracy: 0.7025
# Validation --> Epoch 18 / 100 Step 200 / 516 Loss: 0.8428 Accuracy: 0.6970
# Validation --> Epoch 18 / 100 Step 300 / 516 Loss: 0.8320 Accuracy: 0.7033
# Validation --> Epoch 18 / 100 Step 400 / 516 Loss: 0.8356 Accuracy: 0.7005
# Validation --> Epoch 18 / 100 Step 500 / 516 Loss: 0.8393 Accuracy: 0.6997
# --------------------------------
# End of Epoch 18 / 100
# Epoch 18 / 100 --> Val Loss: 0.8390746684961541 Val Acc: 0.699939489364624
# --------------------------------
# Training --> Epoch 19 / 100 Step 100 / 1313 Loss: 0.9271 Accuracy: 0.6800
# Training --> Epoch 19 / 100 Step 200 / 1313 Loss: 0.9278 Accuracy: 0.6808
# Training --> Epoch 19 / 100 Step 300 / 1313 Loss: 0.9255 Accuracy: 0.6791
# Training --> Epoch 19 / 100 Step 400 / 1313 Loss: 0.9217 Accuracy: 0.6802
# Training --> Epoch 19 / 100 Step 500 / 1313 Loss: 0.9133 Accuracy: 0.6802
# Training --> Epoch 19 / 100 Step 600 / 1313 Loss: 0.9113 Accuracy: 0.6795
# Training --> Epoch 19 / 100 Step 700 / 1313 Loss: 0.9155 Accuracy: 0.6791
# Training --> Epoch 19 / 100 Step 800 / 1313 Loss: 0.9166 Accuracy: 0.6780
# Training --> Epoch 19 / 100 Step 900 / 1313 Loss: 0.9179 Accuracy: 0.6779
# Training --> Epoch 19 / 100 Step 1000 / 1313 Loss: 0.9184 Accuracy: 0.6786
# Training --> Epoch 19 / 100 Step 1100 / 1313 Loss: 0.9171 Accuracy: 0.6797
# Training --> Epoch 19 / 100 Step 1200 / 1313 Loss: 0.9182 Accuracy: 0.6793
# Training --> Epoch 19 / 100 Step 1300 / 1313 Loss: 0.9172 Accuracy: 0.6798
# Validation --> Epoch 19 / 100 Step 100 / 516 Loss: 0.8134 Accuracy: 0.7059
# Validation --> Epoch 19 / 100 Step 200 / 516 Loss: 0.8150 Accuracy: 0.7044
# Validation --> Epoch 19 / 100 Step 300 / 516 Loss: 0.8173 Accuracy: 0.7049
# Validation --> Epoch 19 / 100 Step 400 / 516 Loss: 0.8216 Accuracy: 0.7054
# Validation --> Epoch 19 / 100 Step 500 / 516 Loss: 0.8269 Accuracy: 0.7033
# --------------------------------
# End of Epoch 19 / 100
# Epoch 19 / 100 --> Val Loss: 0.8261510958505232 Val Acc: 0.7037548422813416
# --------------------------------
# Training --> Epoch 20 / 100 Step 100 / 1313 Loss: 0.9238 Accuracy: 0.6759
# Training --> Epoch 20 / 100 Step 200 / 1313 Loss: 0.9133 Accuracy: 0.6850
# Training --> Epoch 20 / 100 Step 300 / 1313 Loss: 0.9194 Accuracy: 0.6807
# Training --> Epoch 20 / 100 Step 400 / 1313 Loss: 0.9080 Accuracy: 0.6843
# Training --> Epoch 20 / 100 Step 500 / 1313 Loss: 0.9085 Accuracy: 0.6846
# Training --> Epoch 20 / 100 Step 600 / 1313 Loss: 0.9105 Accuracy: 0.6844
# Training --> Epoch 20 / 100 Step 700 / 1313 Loss: 0.9117 Accuracy: 0.6836
# Training --> Epoch 20 / 100 Step 800 / 1313 Loss: 0.9079 Accuracy: 0.6857
# Training --> Epoch 20 / 100 Step 900 / 1313 Loss: 0.9090 Accuracy: 0.6850
# Training --> Epoch 20 / 100 Step 1000 / 1313 Loss: 0.9074 Accuracy: 0.6861
# Training --> Epoch 20 / 100 Step 1100 / 1313 Loss: 0.9051 Accuracy: 0.6864
# Training --> Epoch 20 / 100 Step 1200 / 1313 Loss: 0.9080 Accuracy: 0.6849
# Training --> Epoch 20 / 100 Step 1300 / 1313 Loss: 0.9086 Accuracy: 0.6845
# Validation --> Epoch 20 / 100 Step 100 / 516 Loss: 0.8133 Accuracy: 0.7159
# Validation --> Epoch 20 / 100 Step 200 / 516 Loss: 0.8078 Accuracy: 0.7173
# Validation --> Epoch 20 / 100 Step 300 / 516 Loss: 0.8004 Accuracy: 0.7181
# Validation --> Epoch 20 / 100 Step 400 / 516 Loss: 0.8100 Accuracy: 0.7117
# Validation --> Epoch 20 / 100 Step 500 / 516 Loss: 0.8044 Accuracy: 0.7123
# --------------------------------
# End of Epoch 20 / 100
# Epoch 20 / 100 --> Val Loss: 0.806771773007489 Val Acc: 0.7118943929672241
# --------------------------------
# Training --> Epoch 21 / 100 Step 100 / 1313 Loss: 0.9160 Accuracy: 0.6794
# Training --> Epoch 21 / 100 Step 200 / 1313 Loss: 0.9049 Accuracy: 0.6834
# Training --> Epoch 21 / 100 Step 300 / 1313 Loss: 0.9002 Accuracy: 0.6851
# Training --> Epoch 21 / 100 Step 400 / 1313 Loss: 0.8958 Accuracy: 0.6866
# Training --> Epoch 21 / 100 Step 500 / 1313 Loss: 0.8957 Accuracy: 0.6856
# Training --> Epoch 21 / 100 Step 600 / 1313 Loss: 0.8963 Accuracy: 0.6843
# Training --> Epoch 21 / 100 Step 700 / 1313 Loss: 0.8974 Accuracy: 0.6841
# Training --> Epoch 21 / 100 Step 800 / 1313 Loss: 0.8981 Accuracy: 0.6847
# Training --> Epoch 21 / 100 Step 900 / 1313 Loss: 0.8996 Accuracy: 0.6851
# Training --> Epoch 21 / 100 Step 1000 / 1313 Loss: 0.8962 Accuracy: 0.6871
# Training --> Epoch 21 / 100 Step 1100 / 1313 Loss: 0.8967 Accuracy: 0.6873
# Training --> Epoch 21 / 100 Step 1200 / 1313 Loss: 0.8943 Accuracy: 0.6878
# Training --> Epoch 21 / 100 Step 1300 / 1313 Loss: 0.8947 Accuracy: 0.6878
# Validation --> Epoch 21 / 100 Step 100 / 516 Loss: 0.8021 Accuracy: 0.7069
# Validation --> Epoch 21 / 100 Step 200 / 516 Loss: 0.8008 Accuracy: 0.7113
# Validation --> Epoch 21 / 100 Step 300 / 516 Loss: 0.8068 Accuracy: 0.7115
# Validation --> Epoch 21 / 100 Step 400 / 516 Loss: 0.8095 Accuracy: 0.7116
# Validation --> Epoch 21 / 100 Step 500 / 516 Loss: 0.8100 Accuracy: 0.7117
# --------------------------------
# End of Epoch 21 / 100
# Epoch 21 / 100 --> Val Loss: 0.8107395605292431 Val Acc: 0.7119307518005371
# --------------------------------
# Training --> Epoch 22 / 100 Step 100 / 1313 Loss: 0.8815 Accuracy: 0.6934
# Training --> Epoch 22 / 100 Step 200 / 1313 Loss: 0.8755 Accuracy: 0.6978
# Training --> Epoch 22 / 100 Step 300 / 1313 Loss: 0.8742 Accuracy: 0.6934
# Training --> Epoch 22 / 100 Step 400 / 1313 Loss: 0.8825 Accuracy: 0.6937
# Training --> Epoch 22 / 100 Step 500 / 1313 Loss: 0.8835 Accuracy: 0.6925
# Training --> Epoch 22 / 100 Step 600 / 1313 Loss: 0.8815 Accuracy: 0.6931
# Training --> Epoch 22 / 100 Step 700 / 1313 Loss: 0.8854 Accuracy: 0.6938
# Training --> Epoch 22 / 100 Step 800 / 1313 Loss: 0.8840 Accuracy: 0.6941
# Training --> Epoch 22 / 100 Step 900 / 1313 Loss: 0.8833 Accuracy: 0.6945
# Training --> Epoch 22 / 100 Step 1000 / 1313 Loss: 0.8837 Accuracy: 0.6937
# Training --> Epoch 22 / 100 Step 1100 / 1313 Loss: 0.8826 Accuracy: 0.6946
# Training --> Epoch 22 / 100 Step 1200 / 1313 Loss: 0.8846 Accuracy: 0.6940
# Training --> Epoch 22 / 100 Step 1300 / 1313 Loss: 0.8848 Accuracy: 0.6938
# Validation --> Epoch 22 / 100 Step 100 / 516 Loss: 0.8069 Accuracy: 0.7134
# Validation --> Epoch 22 / 100 Step 200 / 516 Loss: 0.8018 Accuracy: 0.7170
# Validation --> Epoch 22 / 100 Step 300 / 516 Loss: 0.7973 Accuracy: 0.7182
# Validation --> Epoch 22 / 100 Step 400 / 516 Loss: 0.7906 Accuracy: 0.7218
# Validation --> Epoch 22 / 100 Step 500 / 516 Loss: 0.7968 Accuracy: 0.7195
# --------------------------------
# End of Epoch 22 / 100
# Epoch 22 / 100 --> Val Loss: 0.7961556626729263 Val Acc: 0.7195615768432617
# --------------------------------
# Training --> Epoch 23 / 100 Step 100 / 1313 Loss: 0.8852 Accuracy: 0.6806
# Training --> Epoch 23 / 100 Step 200 / 1313 Loss: 0.8692 Accuracy: 0.6956
# Training --> Epoch 23 / 100 Step 300 / 1313 Loss: 0.8570 Accuracy: 0.7020
# Training --> Epoch 23 / 100 Step 400 / 1313 Loss: 0.8595 Accuracy: 0.6994
# Training --> Epoch 23 / 100 Step 500 / 1313 Loss: 0.8633 Accuracy: 0.6986
# Training --> Epoch 23 / 100 Step 600 / 1313 Loss: 0.8710 Accuracy: 0.6963
# Training --> Epoch 23 / 100 Step 700 / 1313 Loss: 0.8700 Accuracy: 0.6959
# Training --> Epoch 23 / 100 Step 800 / 1313 Loss: 0.8746 Accuracy: 0.6944
# Training --> Epoch 23 / 100 Step 900 / 1313 Loss: 0.8758 Accuracy: 0.6953
# Training --> Epoch 23 / 100 Step 1000 / 1313 Loss: 0.8708 Accuracy: 0.6973
# Training --> Epoch 23 / 100 Step 1100 / 1313 Loss: 0.8719 Accuracy: 0.6967
# Training --> Epoch 23 / 100 Step 1200 / 1313 Loss: 0.8744 Accuracy: 0.6951
# Training --> Epoch 23 / 100 Step 1300 / 1313 Loss: 0.8715 Accuracy: 0.6966
# Validation --> Epoch 23 / 100 Step 100 / 516 Loss: 0.8252 Accuracy: 0.7131
# Validation --> Epoch 23 / 100 Step 200 / 516 Loss: 0.8184 Accuracy: 0.7127
# Validation --> Epoch 23 / 100 Step 300 / 516 Loss: 0.8044 Accuracy: 0.7170
# Validation --> Epoch 23 / 100 Step 400 / 516 Loss: 0.8002 Accuracy: 0.7197
# Validation --> Epoch 23 / 100 Step 500 / 516 Loss: 0.7942 Accuracy: 0.7206
# --------------------------------
# End of Epoch 23 / 100
# Epoch 23 / 100 --> Val Loss: 0.7924267052448997 Val Acc: 0.7208333611488342
# --------------------------------
# Training --> Epoch 24 / 100 Step 100 / 1313 Loss: 0.8823 Accuracy: 0.6916
# Training --> Epoch 24 / 100 Step 200 / 1313 Loss: 0.8773 Accuracy: 0.6917
# Training --> Epoch 24 / 100 Step 300 / 1313 Loss: 0.8816 Accuracy: 0.6921
# Training --> Epoch 24 / 100 Step 400 / 1313 Loss: 0.8732 Accuracy: 0.6955
# Training --> Epoch 24 / 100 Step 500 / 1313 Loss: 0.8740 Accuracy: 0.6955
# Training --> Epoch 24 / 100 Step 600 / 1313 Loss: 0.8725 Accuracy: 0.6961
# Training --> Epoch 24 / 100 Step 700 / 1313 Loss: 0.8723 Accuracy: 0.6958
# Training --> Epoch 24 / 100 Step 800 / 1313 Loss: 0.8732 Accuracy: 0.6955
# Training --> Epoch 24 / 100 Step 900 / 1313 Loss: 0.8698 Accuracy: 0.6970
# Training --> Epoch 24 / 100 Step 1000 / 1313 Loss: 0.8689 Accuracy: 0.6969
# Training --> Epoch 24 / 100 Step 1100 / 1313 Loss: 0.8702 Accuracy: 0.6965
# Training --> Epoch 24 / 100 Step 1200 / 1313 Loss: 0.8680 Accuracy: 0.6974
# Training --> Epoch 24 / 100 Step 1300 / 1313 Loss: 0.8691 Accuracy: 0.6974
# Validation --> Epoch 24 / 100 Step 100 / 516 Loss: 0.7820 Accuracy: 0.7159
# Validation --> Epoch 24 / 100 Step 200 / 516 Loss: 0.7841 Accuracy: 0.7159
# Validation --> Epoch 24 / 100 Step 300 / 516 Loss: 0.7824 Accuracy: 0.7208
# Validation --> Epoch 24 / 100 Step 400 / 516 Loss: 0.7768 Accuracy: 0.7251
# Validation --> Epoch 24 / 100 Step 500 / 516 Loss: 0.7765 Accuracy: 0.7253
# --------------------------------
# End of Epoch 24 / 100
# Epoch 24 / 100 --> Val Loss: 0.7798696634496829 Val Acc: 0.7234495878219604
# --------------------------------
# Training --> Epoch 25 / 100 Step 100 / 1313 Loss: 0.8757 Accuracy: 0.6938
# Training --> Epoch 25 / 100 Step 200 / 1313 Loss: 0.8670 Accuracy: 0.6975
# Training --> Epoch 25 / 100 Step 300 / 1313 Loss: 0.8575 Accuracy: 0.6995
# Training --> Epoch 25 / 100 Step 400 / 1313 Loss: 0.8579 Accuracy: 0.7003
# Training --> Epoch 25 / 100 Step 500 / 1313 Loss: 0.8556 Accuracy: 0.7024
# Training --> Epoch 25 / 100 Step 600 / 1313 Loss: 0.8551 Accuracy: 0.7031
# Training --> Epoch 25 / 100 Step 700 / 1313 Loss: 0.8547 Accuracy: 0.7041
# Training --> Epoch 25 / 100 Step 800 / 1313 Loss: 0.8533 Accuracy: 0.7037
# Training --> Epoch 25 / 100 Step 900 / 1313 Loss: 0.8541 Accuracy: 0.7032
# Training --> Epoch 25 / 100 Step 1000 / 1313 Loss: 0.8564 Accuracy: 0.7025
# Training --> Epoch 25 / 100 Step 1100 / 1313 Loss: 0.8564 Accuracy: 0.7019
# Training --> Epoch 25 / 100 Step 1200 / 1313 Loss: 0.8591 Accuracy: 0.7014
# Training --> Epoch 25 / 100 Step 1300 / 1313 Loss: 0.8586 Accuracy: 0.7016
# Validation --> Epoch 25 / 100 Step 100 / 516 Loss: 0.7666 Accuracy: 0.7278
# Validation --> Epoch 25 / 100 Step 200 / 516 Loss: 0.7762 Accuracy: 0.7233
# Validation --> Epoch 25 / 100 Step 300 / 516 Loss: 0.7724 Accuracy: 0.7244
# Validation --> Epoch 25 / 100 Step 400 / 516 Loss: 0.7748 Accuracy: 0.7230
# Validation --> Epoch 25 / 100 Step 500 / 516 Loss: 0.7734 Accuracy: 0.7251
# --------------------------------
# End of Epoch 25 / 100
# Epoch 25 / 100 --> Val Loss: 0.7747176012905069 Val Acc: 0.7251090407371521
# --------------------------------
# Training --> Epoch 26 / 100 Step 100 / 1313 Loss: 0.8475 Accuracy: 0.6981
# Training --> Epoch 26 / 100 Step 200 / 1313 Loss: 0.8494 Accuracy: 0.6948
# Training --> Epoch 26 / 100 Step 300 / 1313 Loss: 0.8511 Accuracy: 0.6961
# Training --> Epoch 26 / 100 Step 400 / 1313 Loss: 0.8595 Accuracy: 0.6970
# Training --> Epoch 26 / 100 Step 500 / 1313 Loss: 0.8576 Accuracy: 0.6999
# Training --> Epoch 26 / 100 Step 600 / 1313 Loss: 0.8600 Accuracy: 0.7005
# Training --> Epoch 26 / 100 Step 700 / 1313 Loss: 0.8559 Accuracy: 0.7023
# Training --> Epoch 26 / 100 Step 800 / 1313 Loss: 0.8516 Accuracy: 0.7038
# Training --> Epoch 26 / 100 Step 900 / 1313 Loss: 0.8511 Accuracy: 0.7036
# Training --> Epoch 26 / 100 Step 1000 / 1313 Loss: 0.8553 Accuracy: 0.7021
# Training --> Epoch 26 / 100 Step 1100 / 1313 Loss: 0.8559 Accuracy: 0.7022
# Training --> Epoch 26 / 100 Step 1200 / 1313 Loss: 0.8569 Accuracy: 0.7023
# Training --> Epoch 26 / 100 Step 1300 / 1313 Loss: 0.8565 Accuracy: 0.7025
# Validation --> Epoch 26 / 100 Step 100 / 516 Loss: 0.7649 Accuracy: 0.7269
# Validation --> Epoch 26 / 100 Step 200 / 516 Loss: 0.7598 Accuracy: 0.7242
# Validation --> Epoch 26 / 100 Step 300 / 516 Loss: 0.7658 Accuracy: 0.7242
# Validation --> Epoch 26 / 100 Step 400 / 516 Loss: 0.7687 Accuracy: 0.7247
# Validation --> Epoch 26 / 100 Step 500 / 516 Loss: 0.7762 Accuracy: 0.7219
# --------------------------------
# End of Epoch 26 / 100
# Epoch 26 / 100 --> Val Loss: 0.7785006089265957 Val Acc: 0.7216569781303406
# --------------------------------
# Training --> Epoch 27 / 100 Step 100 / 1313 Loss: 0.8395 Accuracy: 0.7041
# Training --> Epoch 27 / 100 Step 200 / 1313 Loss: 0.8358 Accuracy: 0.7136
# Training --> Epoch 27 / 100 Step 300 / 1313 Loss: 0.8325 Accuracy: 0.7116
# Training --> Epoch 27 / 100 Step 400 / 1313 Loss: 0.8283 Accuracy: 0.7106
# Training --> Epoch 27 / 100 Step 500 / 1313 Loss: 0.8313 Accuracy: 0.7104
# Training --> Epoch 27 / 100 Step 600 / 1313 Loss: 0.8336 Accuracy: 0.7107
# Training --> Epoch 27 / 100 Step 700 / 1313 Loss: 0.8365 Accuracy: 0.7094
# Training --> Epoch 27 / 100 Step 800 / 1313 Loss: 0.8403 Accuracy: 0.7077
# Training --> Epoch 27 / 100 Step 900 / 1313 Loss: 0.8416 Accuracy: 0.7062
# Training --> Epoch 27 / 100 Step 1000 / 1313 Loss: 0.8401 Accuracy: 0.7074
# Training --> Epoch 27 / 100 Step 1100 / 1313 Loss: 0.8416 Accuracy: 0.7067
# Training --> Epoch 27 / 100 Step 1200 / 1313 Loss: 0.8412 Accuracy: 0.7065
# Training --> Epoch 27 / 100 Step 1300 / 1313 Loss: 0.8434 Accuracy: 0.7052
# Validation --> Epoch 27 / 100 Step 100 / 516 Loss: 0.7797 Accuracy: 0.7222
# Validation --> Epoch 27 / 100 Step 200 / 516 Loss: 0.7722 Accuracy: 0.7255
# Validation --> Epoch 27 / 100 Step 300 / 516 Loss: 0.7714 Accuracy: 0.7264
# Validation --> Epoch 27 / 100 Step 400 / 516 Loss: 0.7679 Accuracy: 0.7274
# Validation --> Epoch 27 / 100 Step 500 / 516 Loss: 0.7620 Accuracy: 0.7303
# --------------------------------
# End of Epoch 27 / 100
# Epoch 27 / 100 --> Val Loss: 0.7624123806292696 Val Acc: 0.7300751209259033
# --------------------------------
# Training --> Epoch 28 / 100 Step 100 / 1313 Loss: 0.8178 Accuracy: 0.7091
# Training --> Epoch 28 / 100 Step 200 / 1313 Loss: 0.8253 Accuracy: 0.7108
# Training --> Epoch 28 / 100 Step 300 / 1313 Loss: 0.8304 Accuracy: 0.7102
# Training --> Epoch 28 / 100 Step 400 / 1313 Loss: 0.8347 Accuracy: 0.7084
# Training --> Epoch 28 / 100 Step 500 / 1313 Loss: 0.8392 Accuracy: 0.7051
# Training --> Epoch 28 / 100 Step 600 / 1313 Loss: 0.8437 Accuracy: 0.7032
# Training --> Epoch 28 / 100 Step 700 / 1313 Loss: 0.8407 Accuracy: 0.7050
# Training --> Epoch 28 / 100 Step 800 / 1313 Loss: 0.8373 Accuracy: 0.7059
# Training --> Epoch 28 / 100 Step 900 / 1313 Loss: 0.8397 Accuracy: 0.7052
# Training --> Epoch 28 / 100 Step 1000 / 1313 Loss: 0.8403 Accuracy: 0.7054
# Training --> Epoch 28 / 100 Step 1100 / 1313 Loss: 0.8382 Accuracy: 0.7062
# Training --> Epoch 28 / 100 Step 1200 / 1313 Loss: 0.8398 Accuracy: 0.7060
# Training --> Epoch 28 / 100 Step 1300 / 1313 Loss: 0.8396 Accuracy: 0.7067
# Validation --> Epoch 28 / 100 Step 100 / 516 Loss: 0.7715 Accuracy: 0.7256
# Validation --> Epoch 28 / 100 Step 200 / 516 Loss: 0.7718 Accuracy: 0.7286
# Validation --> Epoch 28 / 100 Step 300 / 516 Loss: 0.7680 Accuracy: 0.7270
# Validation --> Epoch 28 / 100 Step 400 / 516 Loss: 0.7668 Accuracy: 0.7275
# Validation --> Epoch 28 / 100 Step 500 / 516 Loss: 0.7623 Accuracy: 0.7293
# --------------------------------
# End of Epoch 28 / 100
# Epoch 28 / 100 --> Val Loss: 0.7599698853816172 Val Acc: 0.7302688956260681
# --------------------------------
# Training --> Epoch 29 / 100 Step 100 / 1313 Loss: 0.8112 Accuracy: 0.7209
# Training --> Epoch 29 / 100 Step 200 / 1313 Loss: 0.8309 Accuracy: 0.7138
# Training --> Epoch 29 / 100 Step 300 / 1313 Loss: 0.8366 Accuracy: 0.7104
# Training --> Epoch 29 / 100 Step 400 / 1313 Loss: 0.8497 Accuracy: 0.7063
# Training --> Epoch 29 / 100 Step 500 / 1313 Loss: 0.8423 Accuracy: 0.7091
# Training --> Epoch 29 / 100 Step 600 / 1313 Loss: 0.8369 Accuracy: 0.7101
# Training --> Epoch 29 / 100 Step 700 / 1313 Loss: 0.8343 Accuracy: 0.7099
# Training --> Epoch 29 / 100 Step 800 / 1313 Loss: 0.8332 Accuracy: 0.7106
# Training --> Epoch 29 / 100 Step 900 / 1313 Loss: 0.8308 Accuracy: 0.7108
# Training --> Epoch 29 / 100 Step 1000 / 1313 Loss: 0.8309 Accuracy: 0.7105
# Training --> Epoch 29 / 100 Step 1100 / 1313 Loss: 0.8301 Accuracy: 0.7114
# Training --> Epoch 29 / 100 Step 1200 / 1313 Loss: 0.8321 Accuracy: 0.7113
# Training --> Epoch 29 / 100 Step 1300 / 1313 Loss: 0.8324 Accuracy: 0.7117
# Validation --> Epoch 29 / 100 Step 100 / 516 Loss: 0.7404 Accuracy: 0.7303
# Validation --> Epoch 29 / 100 Step 200 / 516 Loss: 0.7508 Accuracy: 0.7289
# Validation --> Epoch 29 / 100 Step 300 / 516 Loss: 0.7548 Accuracy: 0.7294
# Validation --> Epoch 29 / 100 Step 400 / 516 Loss: 0.7535 Accuracy: 0.7303
# Validation --> Epoch 29 / 100 Step 500 / 516 Loss: 0.7521 Accuracy: 0.7304
# --------------------------------
# End of Epoch 29 / 100
# Epoch 29 / 100 --> Val Loss: 0.7524733979457109 Val Acc: 0.7304747700691223
# --------------------------------
# Training --> Epoch 30 / 100 Step 100 / 1313 Loss: 0.8118 Accuracy: 0.7200
# Training --> Epoch 30 / 100 Step 200 / 1313 Loss: 0.8228 Accuracy: 0.7141
# Training --> Epoch 30 / 100 Step 300 / 1313 Loss: 0.8222 Accuracy: 0.7127
# Training --> Epoch 30 / 100 Step 400 / 1313 Loss: 0.8164 Accuracy: 0.7132
# Training --> Epoch 30 / 100 Step 500 / 1313 Loss: 0.8225 Accuracy: 0.7117
# Training --> Epoch 30 / 100 Step 600 / 1313 Loss: 0.8162 Accuracy: 0.7155
# Training --> Epoch 30 / 100 Step 700 / 1313 Loss: 0.8165 Accuracy: 0.7149
# Training --> Epoch 30 / 100 Step 800 / 1313 Loss: 0.8181 Accuracy: 0.7147
# Training --> Epoch 30 / 100 Step 900 / 1313 Loss: 0.8215 Accuracy: 0.7133
# Training --> Epoch 30 / 100 Step 1000 / 1313 Loss: 0.8220 Accuracy: 0.7132
# Training --> Epoch 30 / 100 Step 1100 / 1313 Loss: 0.8225 Accuracy: 0.7132
# Training --> Epoch 30 / 100 Step 1200 / 1313 Loss: 0.8229 Accuracy: 0.7132
# Training --> Epoch 30 / 100 Step 1300 / 1313 Loss: 0.8243 Accuracy: 0.7121
# Validation --> Epoch 30 / 100 Step 100 / 516 Loss: 0.7180 Accuracy: 0.7472
# Validation --> Epoch 30 / 100 Step 200 / 516 Loss: 0.7429 Accuracy: 0.7367
# Validation --> Epoch 30 / 100 Step 300 / 516 Loss: 0.7539 Accuracy: 0.7362
# Validation --> Epoch 30 / 100 Step 400 / 516 Loss: 0.7600 Accuracy: 0.7316
# Validation --> Epoch 30 / 100 Step 500 / 516 Loss: 0.7512 Accuracy: 0.7342
# --------------------------------
# End of Epoch 30 / 100
# Epoch 30 / 100 --> Val Loss: 0.7507835069830103 Val Acc: 0.7351865768432617
# --------------------------------
# Training --> Epoch 31 / 100 Step 100 / 1313 Loss: 0.7850 Accuracy: 0.7278
# Training --> Epoch 31 / 100 Step 200 / 1313 Loss: 0.7945 Accuracy: 0.7252
# Training --> Epoch 31 / 100 Step 300 / 1313 Loss: 0.8015 Accuracy: 0.7229
# Training --> Epoch 31 / 100 Step 400 / 1313 Loss: 0.8092 Accuracy: 0.7182
# Training --> Epoch 31 / 100 Step 500 / 1313 Loss: 0.8134 Accuracy: 0.7174
# Training --> Epoch 31 / 100 Step 600 / 1313 Loss: 0.8153 Accuracy: 0.7180
# Training --> Epoch 31 / 100 Step 700 / 1313 Loss: 0.8184 Accuracy: 0.7171
# Training --> Epoch 31 / 100 Step 800 / 1313 Loss: 0.8193 Accuracy: 0.7162
# Training --> Epoch 31 / 100 Step 900 / 1313 Loss: 0.8181 Accuracy: 0.7165
# Training --> Epoch 31 / 100 Step 1000 / 1313 Loss: 0.8197 Accuracy: 0.7170
# Training --> Epoch 31 / 100 Step 1100 / 1313 Loss: 0.8189 Accuracy: 0.7174
# Training --> Epoch 31 / 100 Step 1200 / 1313 Loss: 0.8171 Accuracy: 0.7174
# Training --> Epoch 31 / 100 Step 1300 / 1313 Loss: 0.8157 Accuracy: 0.7173
# Validation --> Epoch 31 / 100 Step 100 / 516 Loss: 0.7301 Accuracy: 0.7422
# Validation --> Epoch 31 / 100 Step 200 / 516 Loss: 0.7248 Accuracy: 0.7406
# Validation --> Epoch 31 / 100 Step 300 / 516 Loss: 0.7350 Accuracy: 0.7415
# Validation --> Epoch 31 / 100 Step 400 / 516 Loss: 0.7426 Accuracy: 0.7377
# Validation --> Epoch 31 / 100 Step 500 / 516 Loss: 0.7410 Accuracy: 0.7384
# --------------------------------
# End of Epoch 31 / 100
# Epoch 31 / 100 --> Val Loss: 0.7425750453573788 Val Acc: 0.7381419539451599
# --------------------------------
# Training --> Epoch 32 / 100 Step 100 / 1313 Loss: 0.8384 Accuracy: 0.7109
# Training --> Epoch 32 / 100 Step 200 / 1313 Loss: 0.7984 Accuracy: 0.7212
# Training --> Epoch 32 / 100 Step 300 / 1313 Loss: 0.8073 Accuracy: 0.7189
# Training --> Epoch 32 / 100 Step 400 / 1313 Loss: 0.8064 Accuracy: 0.7190
# Training --> Epoch 32 / 100 Step 500 / 1313 Loss: 0.8104 Accuracy: 0.7184
# Training --> Epoch 32 / 100 Step 600 / 1313 Loss: 0.8114 Accuracy: 0.7189
# Training --> Epoch 32 / 100 Step 700 / 1313 Loss: 0.8072 Accuracy: 0.7209
# Training --> Epoch 32 / 100 Step 800 / 1313 Loss: 0.8071 Accuracy: 0.7203
# Training --> Epoch 32 / 100 Step 900 / 1313 Loss: 0.8084 Accuracy: 0.7199
# Training --> Epoch 32 / 100 Step 1000 / 1313 Loss: 0.8091 Accuracy: 0.7207
# Training --> Epoch 32 / 100 Step 1100 / 1313 Loss: 0.8129 Accuracy: 0.7192
# Training --> Epoch 32 / 100 Step 1200 / 1313 Loss: 0.8129 Accuracy: 0.7193
# Training --> Epoch 32 / 100 Step 1300 / 1313 Loss: 0.8124 Accuracy: 0.7186
# Validation --> Epoch 32 / 100 Step 100 / 516 Loss: 0.7415 Accuracy: 0.7403
# Validation --> Epoch 32 / 100 Step 200 / 516 Loss: 0.7400 Accuracy: 0.7384
# Validation --> Epoch 32 / 100 Step 300 / 516 Loss: 0.7475 Accuracy: 0.7327
# Validation --> Epoch 32 / 100 Step 400 / 516 Loss: 0.7488 Accuracy: 0.7329
# Validation --> Epoch 32 / 100 Step 500 / 516 Loss: 0.7521 Accuracy: 0.7327
# --------------------------------
# End of Epoch 32 / 100
# ...
# Training --> Epoch 90 / 100 Step 900 / 1313 Loss: 0.6300 Accuracy: 0.7797
# Training --> Epoch 90 / 100 Step 1000 / 1313 Loss: 0.6306 Accuracy: 0.7790
# Training --> Epoch 90 / 100 Step 1100 / 1313 Loss: 0.6338 Accuracy: 0.7774
# Training --> Epoch 90 / 100 Step 1200 / 1313 Loss: 0.6326 Accuracy: 0.7783
# Training --> Epoch 90 / 100 Step 1300 / 1313 Loss: 0.6338 Accuracy: 0.7782
# Validation --> Epoch 90 / 100 Step 100 / 516 Loss: 0.6017 Accuracy: 0.7853
# Validation --> Epoch 90 / 100 Step 200 / 516 Loss: 0.6026 Accuracy: 0.7942
# Validation --> Epoch 90 / 100 Step 300 / 516 Loss: 0.6060 Accuracy: 0.7914
# Validation --> Epoch 90 / 100 Step 400 / 516 Loss: 0.6079 Accuracy: 0.7895
# Validation --> Epoch 90 / 100 Step 500 / 516 Loss: 0.6081 Accuracy: 0.7883
# --------------------------------
# End of Epoch 90 / 100
# Epoch 90 / 100 --> Val Loss: 0.6099251576865367 Val Acc: 0.7885053157806396
# --------------------------------
# Training --> Epoch 91 / 100 Step 100 / 1313 Loss: 0.6061 Accuracy: 0.7922
# Training --> Epoch 91 / 100 Step 200 / 1313 Loss: 0.6220 Accuracy: 0.7869
# Training --> Epoch 91 / 100 Step 300 / 1313 Loss: 0.6365 Accuracy: 0.7790
# Training --> Epoch 91 / 100 Step 400 / 1313 Loss: 0.6316 Accuracy: 0.7801
# Training --> Epoch 91 / 100 Step 500 / 1313 Loss: 0.6300 Accuracy: 0.7811
# Training --> Epoch 91 / 100 Step 600 / 1313 Loss: 0.6289 Accuracy: 0.7823
# Training --> Epoch 91 / 100 Step 700 / 1313 Loss: 0.6338 Accuracy: 0.7802
# Training --> Epoch 91 / 100 Step 800 / 1313 Loss: 0.6331 Accuracy: 0.7806
# Training --> Epoch 91 / 100 Step 900 / 1313 Loss: 0.6339 Accuracy: 0.7805
# Training --> Epoch 91 / 100 Step 1000 / 1313 Loss: 0.6343 Accuracy: 0.7798
# Training --> Epoch 91 / 100 Step 1100 / 1313 Loss: 0.6342 Accuracy: 0.7805
# Training --> Epoch 91 / 100 Step 1200 / 1313 Loss: 0.6322 Accuracy: 0.7807
# Training --> Epoch 91 / 100 Step 1300 / 1313 Loss: 0.6315 Accuracy: 0.7812
# Validation --> Epoch 91 / 100 Step 100 / 516 Loss: 0.6336 Accuracy: 0.7891
# Validation --> Epoch 91 / 100 Step 200 / 516 Loss: 0.6180 Accuracy: 0.7887
# Validation --> Epoch 91 / 100 Step 300 / 516 Loss: 0.6013 Accuracy: 0.7912
# Validation --> Epoch 91 / 100 Step 400 / 516 Loss: 0.6041 Accuracy: 0.7891
# Validation --> Epoch 91 / 100 Step 500 / 516 Loss: 0.6066 Accuracy: 0.7895
# --------------------------------
# End of Epoch 91 / 100
# Epoch 91 / 100 --> Val Loss: 0.6067383898378804 Val Acc: 0.7895106673240662
# --------------------------------
# Training --> Epoch 92 / 100 Step 100 / 1313 Loss: 0.5934 Accuracy: 0.7941
# Training --> Epoch 92 / 100 Step 200 / 1313 Loss: 0.6146 Accuracy: 0.7870
# Training --> Epoch 92 / 100 Step 300 / 1313 Loss: 0.6350 Accuracy: 0.7803
# Training --> Epoch 92 / 100 Step 400 / 1313 Loss: 0.6348 Accuracy: 0.7805
# Training --> Epoch 92 / 100 Step 500 / 1313 Loss: 0.6367 Accuracy: 0.7796
# Training --> Epoch 92 / 100 Step 600 / 1313 Loss: 0.6341 Accuracy: 0.7799
# Training --> Epoch 92 / 100 Step 700 / 1313 Loss: 0.6370 Accuracy: 0.7794
# Training --> Epoch 92 / 100 Step 800 / 1313 Loss: 0.6351 Accuracy: 0.7804
# Training --> Epoch 92 / 100 Step 900 / 1313 Loss: 0.6317 Accuracy: 0.7816
# Training --> Epoch 92 / 100 Step 1000 / 1313 Loss: 0.6320 Accuracy: 0.7808
# Training --> Epoch 92 / 100 Step 1100 / 1313 Loss: 0.6332 Accuracy: 0.7800
# Training --> Epoch 92 / 100 Step 1200 / 1313 Loss: 0.6354 Accuracy: 0.7793
# Training --> Epoch 92 / 100 Step 1300 / 1313 Loss: 0.6365 Accuracy: 0.7789
# Validation --> Epoch 92 / 100 Step 100 / 516 Loss: 0.5852 Accuracy: 0.7972
# Validation --> Epoch 92 / 100 Step 200 / 516 Loss: 0.6010 Accuracy: 0.7897
# Validation --> Epoch 92 / 100 Step 300 / 516 Loss: 0.5992 Accuracy: 0.7928
# Validation --> Epoch 92 / 100 Step 400 / 516 Loss: 0.6025 Accuracy: 0.7912
# Validation --> Epoch 92 / 100 Step 500 / 516 Loss: 0.6067 Accuracy: 0.7895
# --------------------------------
# End of Epoch 92 / 100
# Epoch 92 / 100 --> Val Loss: 0.6064005897257679 Val Acc: 0.7891109585762024
# --------------------------------
# Training --> Epoch 93 / 100 Step 100 / 1313 Loss: 0.6190 Accuracy: 0.7919
# Training --> Epoch 93 / 100 Step 200 / 1313 Loss: 0.6381 Accuracy: 0.7819
# Training --> Epoch 93 / 100 Step 300 / 1313 Loss: 0.6360 Accuracy: 0.7834
# Training --> Epoch 93 / 100 Step 400 / 1313 Loss: 0.6245 Accuracy: 0.7852
# Training --> Epoch 93 / 100 Step 500 / 1313 Loss: 0.6264 Accuracy: 0.7840
# Training --> Epoch 93 / 100 Step 600 / 1313 Loss: 0.6224 Accuracy: 0.7856
# Training --> Epoch 93 / 100 Step 700 / 1313 Loss: 0.6243 Accuracy: 0.7864
# Training --> Epoch 93 / 100 Step 800 / 1313 Loss: 0.6244 Accuracy: 0.7863
# Training --> Epoch 93 / 100 Step 900 / 1313 Loss: 0.6266 Accuracy: 0.7858
# Training --> Epoch 93 / 100 Step 1000 / 1313 Loss: 0.6296 Accuracy: 0.7840
# Training --> Epoch 93 / 100 Step 1100 / 1313 Loss: 0.6325 Accuracy: 0.7831
# Training --> Epoch 93 / 100 Step 1200 / 1313 Loss: 0.6343 Accuracy: 0.7824
# Training --> Epoch 93 / 100 Step 1300 / 1313 Loss: 0.6351 Accuracy: 0.7819
# Validation --> Epoch 93 / 100 Step 100 / 516 Loss: 0.6047 Accuracy: 0.7972
# Validation --> Epoch 93 / 100 Step 200 / 516 Loss: 0.6192 Accuracy: 0.7844
# Validation --> Epoch 93 / 100 Step 300 / 516 Loss: 0.6235 Accuracy: 0.7830
# Validation --> Epoch 93 / 100 Step 400 / 516 Loss: 0.6219 Accuracy: 0.7837
# Validation --> Epoch 93 / 100 Step 500 / 516 Loss: 0.6161 Accuracy: 0.7865
# --------------------------------
# End of Epoch 93 / 100
# Epoch 93 / 100 --> Val Loss: 0.6156861447664195 Val Acc: 0.7861192226409912
# --------------------------------
# Training --> Epoch 94 / 100 Step 100 / 1313 Loss: 0.6082 Accuracy: 0.7941
# Training --> Epoch 94 / 100 Step 200 / 1313 Loss: 0.6103 Accuracy: 0.7919
# Training --> Epoch 94 / 100 Step 300 / 1313 Loss: 0.6185 Accuracy: 0.7887
# Training --> Epoch 94 / 100 Step 400 / 1313 Loss: 0.6220 Accuracy: 0.7862
# Training --> Epoch 94 / 100 Step 500 / 1313 Loss: 0.6222 Accuracy: 0.7851
# Training --> Epoch 94 / 100 Step 600 / 1313 Loss: 0.6214 Accuracy: 0.7849
# Training --> Epoch 94 / 100 Step 700 / 1313 Loss: 0.6256 Accuracy: 0.7832
# Training --> Epoch 94 / 100 Step 800 / 1313 Loss: 0.6255 Accuracy: 0.7831
# Training --> Epoch 94 / 100 Step 900 / 1313 Loss: 0.6269 Accuracy: 0.7823
# Training --> Epoch 94 / 100 Step 1000 / 1313 Loss: 0.6301 Accuracy: 0.7813
# Training --> Epoch 94 / 100 Step 1100 / 1313 Loss: 0.6281 Accuracy: 0.7825
# Training --> Epoch 94 / 100 Step 1200 / 1313 Loss: 0.6267 Accuracy: 0.7827
# Training --> Epoch 94 / 100 Step 1300 / 1313 Loss: 0.6261 Accuracy: 0.7826
# Validation --> Epoch 94 / 100 Step 100 / 516 Loss: 0.6104 Accuracy: 0.7869
# Validation --> Epoch 94 / 100 Step 200 / 516 Loss: 0.6121 Accuracy: 0.7853
# Validation --> Epoch 94 / 100 Step 300 / 516 Loss: 0.6142 Accuracy: 0.7865
# Validation --> Epoch 94 / 100 Step 400 / 516 Loss: 0.6149 Accuracy: 0.7882
# Validation --> Epoch 94 / 100 Step 500 / 516 Loss: 0.6188 Accuracy: 0.7866
# --------------------------------
# End of Epoch 94 / 100
# Epoch 94 / 100 --> Val Loss: 0.619641454847053 Val Acc: 0.7860586643218994
# --------------------------------
# Training --> Epoch 95 / 100 Step 100 / 1313 Loss: 0.6130 Accuracy: 0.7903
# Training --> Epoch 95 / 100 Step 200 / 1313 Loss: 0.6148 Accuracy: 0.7877
# Training --> Epoch 95 / 100 Step 300 / 1313 Loss: 0.6135 Accuracy: 0.7897
# Training --> Epoch 95 / 100 Step 400 / 1313 Loss: 0.6133 Accuracy: 0.7877
# Training --> Epoch 95 / 100 Step 500 / 1313 Loss: 0.6162 Accuracy: 0.7861
# Training --> Epoch 95 / 100 Step 600 / 1313 Loss: 0.6238 Accuracy: 0.7847
# Training --> Epoch 95 / 100 Step 700 / 1313 Loss: 0.6256 Accuracy: 0.7849
# Training --> Epoch 95 / 100 Step 800 / 1313 Loss: 0.6264 Accuracy: 0.7847
# Training --> Epoch 95 / 100 Step 900 / 1313 Loss: 0.6295 Accuracy: 0.7826
# Training --> Epoch 95 / 100 Step 1000 / 1313 Loss: 0.6304 Accuracy: 0.7821
# Training --> Epoch 95 / 100 Step 1100 / 1313 Loss: 0.6311 Accuracy: 0.7819
# Training --> Epoch 95 / 100 Step 1200 / 1313 Loss: 0.6329 Accuracy: 0.7817
# Training --> Epoch 95 / 100 Step 1300 / 1313 Loss: 0.6321 Accuracy: 0.7817
# Validation --> Epoch 95 / 100 Step 100 / 516 Loss: 0.6342 Accuracy: 0.7853
# Validation --> Epoch 95 / 100 Step 200 / 516 Loss: 0.6199 Accuracy: 0.7850
# Validation --> Epoch 95 / 100 Step 300 / 516 Loss: 0.6123 Accuracy: 0.7876
# Validation --> Epoch 95 / 100 Step 400 / 516 Loss: 0.6126 Accuracy: 0.7889
# Validation --> Epoch 95 / 100 Step 500 / 516 Loss: 0.6114 Accuracy: 0.7896
# --------------------------------
# End of Epoch 95 / 100
# Epoch 95 / 100 --> Val Loss: 0.6127475237603798 Val Acc: 0.7891109585762024
# --------------------------------
# Training --> Epoch 96 / 100 Step 100 / 1313 Loss: 0.6180 Accuracy: 0.7925
# Training --> Epoch 96 / 100 Step 200 / 1313 Loss: 0.6014 Accuracy: 0.7970
# Training --> Epoch 96 / 100 Step 300 / 1313 Loss: 0.6140 Accuracy: 0.7926
# Training --> Epoch 96 / 100 Step 400 / 1313 Loss: 0.6122 Accuracy: 0.7919
# Training --> Epoch 96 / 100 Step 500 / 1313 Loss: 0.6205 Accuracy: 0.7866
# Training --> Epoch 96 / 100 Step 600 / 1313 Loss: 0.6226 Accuracy: 0.7860
# Training --> Epoch 96 / 100 Step 700 / 1313 Loss: 0.6215 Accuracy: 0.7864
# Training --> Epoch 96 / 100 Step 800 / 1313 Loss: 0.6237 Accuracy: 0.7849
# Training --> Epoch 96 / 100 Step 900 / 1313 Loss: 0.6277 Accuracy: 0.7833
# Training --> Epoch 96 / 100 Step 1000 / 1313 Loss: 0.6275 Accuracy: 0.7834
# Training --> Epoch 96 / 100 Step 1100 / 1313 Loss: 0.6267 Accuracy: 0.7835
# Training --> Epoch 96 / 100 Step 1200 / 1313 Loss: 0.6281 Accuracy: 0.7836
# Training --> Epoch 96 / 100 Step 1300 / 1313 Loss: 0.6295 Accuracy: 0.7830
# Validation --> Epoch 96 / 100 Step 100 / 516 Loss: 0.5870 Accuracy: 0.7922
# Validation --> Epoch 96 / 100 Step 200 / 516 Loss: 0.5902 Accuracy: 0.7914
# Validation --> Epoch 96 / 100 Step 300 / 516 Loss: 0.5948 Accuracy: 0.7935
# Validation --> Epoch 96 / 100 Step 400 / 516 Loss: 0.5944 Accuracy: 0.7947
# Validation --> Epoch 96 / 100 Step 500 / 516 Loss: 0.5966 Accuracy: 0.7937
# --------------------------------
# End of Epoch 96 / 100
# Epoch 96 / 100 --> Val Loss: 0.5979148876066356 Val Acc: 0.7935562133789062
# --------------------------------
# Training --> Epoch 97 / 100 Step 100 / 1313 Loss: 0.5961 Accuracy: 0.7916
# Training --> Epoch 97 / 100 Step 200 / 1313 Loss: 0.6123 Accuracy: 0.7802
# Training --> Epoch 97 / 100 Step 300 / 1313 Loss: 0.6150 Accuracy: 0.7789
# Training --> Epoch 97 / 100 Step 400 / 1313 Loss: 0.6179 Accuracy: 0.7784
# Training --> Epoch 97 / 100 Step 500 / 1313 Loss: 0.6236 Accuracy: 0.7782
# Training --> Epoch 97 / 100 Step 600 / 1313 Loss: 0.6215 Accuracy: 0.7799
# Training --> Epoch 97 / 100 Step 700 / 1313 Loss: 0.6207 Accuracy: 0.7820
# Training --> Epoch 97 / 100 Step 800 / 1313 Loss: 0.6213 Accuracy: 0.7826
# Training --> Epoch 97 / 100 Step 900 / 1313 Loss: 0.6220 Accuracy: 0.7826
# Training --> Epoch 97 / 100 Step 1000 / 1313 Loss: 0.6219 Accuracy: 0.7826
# Training --> Epoch 97 / 100 Step 1100 / 1313 Loss: 0.6252 Accuracy: 0.7817
# Training --> Epoch 97 / 100 Step 1200 / 1313 Loss: 0.6244 Accuracy: 0.7822
# Training --> Epoch 97 / 100 Step 1300 / 1313 Loss: 0.6271 Accuracy: 0.7817
# Validation --> Epoch 97 / 100 Step 100 / 516 Loss: 0.5972 Accuracy: 0.7906
# Validation --> Epoch 97 / 100 Step 200 / 516 Loss: 0.5921 Accuracy: 0.7945
# Validation --> Epoch 97 / 100 Step 300 / 516 Loss: 0.5985 Accuracy: 0.7918
# Validation --> Epoch 97 / 100 Step 400 / 516 Loss: 0.5953 Accuracy: 0.7912
# Validation --> Epoch 97 / 100 Step 500 / 516 Loss: 0.5971 Accuracy: 0.7941
# --------------------------------
# End of Epoch 97 / 100
# Epoch 97 / 100 --> Val Loss: 0.5962821594042371 Val Acc: 0.794428288936615
# --------------------------------
# Training --> Epoch 98 / 100 Step 100 / 1313 Loss: 0.6419 Accuracy: 0.7681
# Training --> Epoch 98 / 100 Step 200 / 1313 Loss: 0.6232 Accuracy: 0.7820
# Training --> Epoch 98 / 100 Step 300 / 1313 Loss: 0.6386 Accuracy: 0.7789
# Training --> Epoch 98 / 100 Step 400 / 1313 Loss: 0.6346 Accuracy: 0.7795
# Training --> Epoch 98 / 100 Step 500 / 1313 Loss: 0.6357 Accuracy: 0.7792
# Training --> Epoch 98 / 100 Step 600 / 1313 Loss: 0.6349 Accuracy: 0.7792
# Training --> Epoch 98 / 100 Step 700 / 1313 Loss: 0.6317 Accuracy: 0.7820
# Training --> Epoch 98 / 100 Step 800 / 1313 Loss: 0.6336 Accuracy: 0.7810
# Training --> Epoch 98 / 100 Step 900 / 1313 Loss: 0.6335 Accuracy: 0.7801
# Training --> Epoch 98 / 100 Step 1000 / 1313 Loss: 0.6333 Accuracy: 0.7792
# Training --> Epoch 98 / 100 Step 1100 / 1313 Loss: 0.6312 Accuracy: 0.7791
# Training --> Epoch 98 / 100 Step 1200 / 1313 Loss: 0.6332 Accuracy: 0.7782
# Training --> Epoch 98 / 100 Step 1300 / 1313 Loss: 0.6336 Accuracy: 0.7791
# Validation --> Epoch 98 / 100 Step 100 / 516 Loss: 0.6025 Accuracy: 0.7844
# Validation --> Epoch 98 / 100 Step 200 / 516 Loss: 0.5959 Accuracy: 0.7906
# Validation --> Epoch 98 / 100 Step 300 / 516 Loss: 0.6057 Accuracy: 0.7868
# Validation --> Epoch 98 / 100 Step 400 / 516 Loss: 0.6175 Accuracy: 0.7858
# Validation --> Epoch 98 / 100 Step 500 / 516 Loss: 0.6152 Accuracy: 0.7845
# --------------------------------
# End of Epoch 98 / 100
# Epoch 98 / 100 --> Val Loss: 0.617635942706766 Val Acc: 0.7838541865348816
# --------------------------------
# Training --> Epoch 99 / 100 Step 100 / 1313 Loss: 0.6274 Accuracy: 0.7809
# Training --> Epoch 99 / 100 Step 200 / 1313 Loss: 0.6241 Accuracy: 0.7828
# Training --> Epoch 99 / 100 Step 300 / 1313 Loss: 0.6272 Accuracy: 0.7834
# Training --> Epoch 99 / 100 Step 400 / 1313 Loss: 0.6226 Accuracy: 0.7843
# Training --> Epoch 99 / 100 Step 500 / 1313 Loss: 0.6216 Accuracy: 0.7834
# Training --> Epoch 99 / 100 Step 600 / 1313 Loss: 0.6200 Accuracy: 0.7845
# Training --> Epoch 99 / 100 Step 700 / 1313 Loss: 0.6236 Accuracy: 0.7823
# Training --> Epoch 99 / 100 Step 800 / 1313 Loss: 0.6249 Accuracy: 0.7827
# Training --> Epoch 99 / 100 Step 900 / 1313 Loss: 0.6218 Accuracy: 0.7843
# Training --> Epoch 99 / 100 Step 1000 / 1313 Loss: 0.6223 Accuracy: 0.7843
# Training --> Epoch 99 / 100 Step 1100 / 1313 Loss: 0.6234 Accuracy: 0.7837
# Training --> Epoch 99 / 100 Step 1200 / 1313 Loss: 0.6234 Accuracy: 0.7834
# Training --> Epoch 99 / 100 Step 1300 / 1313 Loss: 0.6243 Accuracy: 0.7830
# Validation --> Epoch 99 / 100 Step 100 / 516 Loss: 0.6327 Accuracy: 0.7859
# Validation --> Epoch 99 / 100 Step 200 / 516 Loss: 0.6212 Accuracy: 0.7895
# Validation --> Epoch 99 / 100 Step 300 / 516 Loss: 0.6311 Accuracy: 0.7852
# Validation --> Epoch 99 / 100 Step 400 / 516 Loss: 0.6259 Accuracy: 0.7856
# Validation --> Epoch 99 / 100 Step 500 / 516 Loss: 0.6346 Accuracy: 0.7816
# --------------------------------
# End of Epoch 99 / 100
# Epoch 99 / 100 --> Val Loss: 0.6348044519392095 Val Acc: 0.7813832759857178
# --------------------------------
# Training --> Epoch 100 / 100 Step 100 / 1313 Loss: 0.6254 Accuracy: 0.7834
# Training --> Epoch 100 / 100 Step 200 / 1313 Loss: 0.6235 Accuracy: 0.7864
# Training --> Epoch 100 / 100 Step 300 / 1313 Loss: 0.6101 Accuracy: 0.7897
# Training --> Epoch 100 / 100 Step 400 / 1313 Loss: 0.6120 Accuracy: 0.7863
# Training --> Epoch 100 / 100 Step 500 / 1313 Loss: 0.6122 Accuracy: 0.7863
# Training --> Epoch 100 / 100 Step 600 / 1313 Loss: 0.6158 Accuracy: 0.7851
# Training --> Epoch 100 / 100 Step 700 / 1313 Loss: 0.6200 Accuracy: 0.7843
# Training --> Epoch 100 / 100 Step 800 / 1313 Loss: 0.6192 Accuracy: 0.7842
# Training --> Epoch 100 / 100 Step 900 / 1313 Loss: 0.6220 Accuracy: 0.7834
# Training --> Epoch 100 / 100 Step 1000 / 1313 Loss: 0.6252 Accuracy: 0.7822
# Training --> Epoch 100 / 100 Step 1100 / 1313 Loss: 0.6258 Accuracy: 0.7820
# Training --> Epoch 100 / 100 Step 1200 / 1313 Loss: 0.6262 Accuracy: 0.7822
# Training --> Epoch 100 / 100 Step 1300 / 1313 Loss: 0.6246 Accuracy: 0.7830
# Validation --> Epoch 100 / 100 Step 100 / 516 Loss: 0.5923 Accuracy: 0.7941
# Validation --> Epoch 100 / 100 Step 200 / 516 Loss: 0.5903 Accuracy: 0.7962
# Validation --> Epoch 100 / 100 Step 300 / 516 Loss: 0.5991 Accuracy: 0.7926
# Validation --> Epoch 100 / 100 Step 400 / 516 Loss: 0.5948 Accuracy: 0.7935
# Validation --> Epoch 100 / 100 Step 500 / 516 Loss: 0.5939 Accuracy: 0.7944
# --------------------------------
# End of Epoch 100 / 100
# Epoch 100 / 100 --> Val Loss: 0.5934513312901637 Val Acc: 0.7944040894508362
# --------------------------------

# %% [markdown]
# ### Bench Marking

# %%
run_benchmark()
# Out:
# Loading best model...
# Loading best model: Model_MiniVGG_97_d12d.pt (accuracy: 0.7944)
# Model pruned using PyTorch pruning!
# Converted to FP16!
# Optimizing model for MPS...
# Model optimized successfully!
#
# Warming up...
# Warm-up complete!
#
# Running inference on test dataset...
# Processed 100 samples...
# Processed 200 samples...
# Processed 300 samples...
# Processed 400 samples...
# Processed 500 samples...
# Processed 600 samples...
# Processed 700 samples...
# Processed 800 samples...
# Processed 900 samples...
# Processed 1000 samples...
# Processed 1100 samples...
# Processed 1200 samples...
# Processed 1300 samples...
# Processed 1400 samples...
# Processed 1500 samples...
# Results saved to submission.csv
#
# Benchmark Summary:
# Average latency: 0.52 ms
# Min latency: 0.47 ms
# Max latency: 1.22 ms
# Expected Score: 1.5259507159516512

# %% [markdown]
# #### I started by making a VGG11 model and got accuracy of about 65%. Then I made VGG19 that resulted in better accuracy of about 85% but the latency was too high. So I tried to make the MiniVGG that gave me the accuracy of 80% and a better latency. I levereged my macbook air GPU by converting the model into the coreML model which resulted in a 3x speed up. I tried various optimization techniques. I started by the built in optimization flags and functions that pytorch provides. I also applied pruning that resulted in a very bad accuracy drop. I changed from FP32 to FP16 that made my model faster without a drop in accuracy. I also tried to apply quantization but it wasn't supported for mac devices.
